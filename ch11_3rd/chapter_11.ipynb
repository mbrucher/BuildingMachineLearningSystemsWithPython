# %% [markdown]
# # Building Machine Learning Systems with Python - Chapter 11

# %% [markdown]
# In this chapter we will create a music genre classifier. While the ML algorithm itself (logistic regression) is nothing fancy by now, we will look into fancy features like Fast Fourier Transforms and Mel Frequency Cepstral Coefficients, use P/R and ROC curves to analyze what works best and then figure out which version to use.
#
# This code is supporting material for the book `Building Machine Learning Systems with Python` by [Willi Richert](https://www.linkedin.com/in/willirichert/) and [Luis Pedro Coelho](https://www.linkedin.com/in/luispedrocoelho/)  published by PACKT Publishing. It is made available under the MIT License.
#
# All code examples use Python in version...

# %%
import sys
sys.version
# Out:
# '3.6.3 |Anaconda custom (64-bit)| (default, Nov  8 2017, 15:10:56) [MSC v.1900 64 bit (AMD64)]'

# %% [markdown]
# ## Utilities we will need

# %%
import os
import glob 
from pathlib import Path

CHART_DIR = "charts"
if not Path(CHART_DIR).exists():
    os.mkdir(CHART_DIR)

DATA_DIR = "data"
if not Path(DATA_DIR).exists():
    os.mkdir(DATA_DIR)

GENRE_DIR = Path(DATA_DIR) / 'genres'

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn')

import numpy as np
import scipy

DPI = 100

import collections
import csv

def save_png(name):
    fn = 'B09124_11_%s.png'%name # please ignore, it just helps our publisher :-)
    plt.savefig(str(Path(CHART_DIR) / fn), bbox_inches="tight")
    
    
def plot_pr(auc_score, name, precision, recall, label=None, plot_nr=None):
    plt.figure(num=None, figsize=(5, 4), dpi=DPI)
    plt.grid(True)
    plt.fill_between(recall, precision, alpha=0.5)
    plt.plot(recall, precision, lw=1)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('P/R curve (AUC=%0.2f) / %s' % (auc_score, label))
    filename = name.replace(" ", "_")
    save_png("%s_pr_%s" % (plot_nr, filename))
    
def plot_roc(auc_score, name, tpr, fpr, label=None, plot_nr=None):
    plt.figure(num=None, figsize=(5, 4), dpi=DPI)
    plt.grid(True)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr)
    plt.fill_between(fpr, tpr, alpha=0.5)
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC curve (AUC = %0.2f) / %s' % (auc_score, label), verticalalignment="bottom")
    plt.legend(loc="lower right")
    save_png('%i_auc_%s' % (plot_nr, name))

# %% [markdown]
# ## Preparing the data

# %%
import urllib.request

genre_fn = 'http://opihi.cs.uvic.ca/sound/genres.tar.gz'
urllib.request.urlretrieve(genre_fn, Path(DATA_DIR) / 'genres.tar.gz')
# Out:
# (WindowsPath('data/genres.tar.gz'), <http.client.HTTPMessage at 0x251aac98518>)

# %%
import tarfile

cwd = os.getcwd()

os.chdir(DATA_DIR)

try:
    f = tarfile.open('genres.tar.gz', 'r:gz')
    try: 
        f.extractall()
    finally: 
        f.close()
finally:
    os.chdir(cwd)

# %% [markdown]
# Download and install https://sourceforge.net/projects/sox/files/sox/. For this notebook, we are using SOX 14.4.2 to convert the downloaded genre files from `.au` into `.wav` format, which is easier to handle.

# %%
SOX_PATH = r'C:\Program Files (x86)\sox-14-4-2'

# %%
for au_fn in Path(GENRE_DIR).glob('**/*.au'):
    print(au_fn)
    !"{SOX_PATH}/sox.exe" {au_fn} {au_fn.with_suffix('.wav')}
# Out:
# data\genres\blues\blues.00000.au
# data\genres\blues\blues.00001.au
# data\genres\blues\blues.00002.au
# data\genres\blues\blues.00003.au
# data\genres\blues\blues.00004.au
# data\genres\blues\blues.00005.au
# data\genres\blues\blues.00006.au
# data\genres\blues\blues.00007.au
# data\genres\blues\blues.00008.au
# data\genres\blues\blues.00009.au
# data\genres\blues\blues.00010.au
# data\genres\blues\blues.00011.au
# data\genres\blues\blues.00012.au
# data\genres\blues\blues.00013.au
# data\genres\blues\blues.00014.au
# data\genres\blues\blues.00015.au
# data\genres\blues\blues.00016.au
# data\genres\blues\blues.00017.au
# data\genres\blues\blues.00018.au
# data\genres\blues\blues.00019.au
# data\genres\blues\blues.00020.au
# data\genres\blues\blues.00021.au
# data\genres\blues\blues.00022.au
# data\genres\blues\blues.00023.au
# data\genres\blues\blues.00024.au
# data\genres\blues\blues.00025.au
# data\genres\blues\blues.00026.au
# data\genres\blues\blues.00027.au
# data\genres\blues\blues.00028.au
# data\genres\blues\blues.00029.au
# data\genres\blues\blues.00030.au
# data\genres\blues\blues.00031.au
# data\genres\blues\blues.00032.au
# data\genres\blues\blues.00033.au
# data\genres\blues\blues.00034.au
# data\genres\blues\blues.00035.au
# data\genres\blues\blues.00036.au
# data\genres\blues\blues.00037.au
# data\genres\blues\blues.00038.au
# data\genres\blues\blues.00039.au
# data\genres\blues\blues.00040.au
# data\genres\blues\blues.00041.au
# data\genres\blues\blues.00042.au
# data\genres\blues\blues.00043.au
# data\genres\blues\blues.00044.au
# data\genres\blues\blues.00045.au
# data\genres\blues\blues.00046.au
# data\genres\blues\blues.00047.au
# data\genres\blues\blues.00048.au
# data\genres\blues\blues.00049.au
# data\genres\blues\blues.00050.au
# data\genres\blues\blues.00051.au
# data\genres\blues\blues.00052.au
# data\genres\blues\blues.00053.au
# data\genres\blues\blues.00054.au
# data\genres\blues\blues.00055.au
# data\genres\blues\blues.00056.au
# data\genres\blues\blues.00057.au
# data\genres\blues\blues.00058.au
# data\genres\blues\blues.00059.au
# data\genres\blues\blues.00060.au
# data\genres\blues\blues.00061.au
# data\genres\blues\blues.00062.au
# data\genres\blues\blues.00063.au
# data\genres\blues\blues.00064.au
# data\genres\blues\blues.00065.au
# data\genres\blues\blues.00066.au
# data\genres\blues\blues.00067.au
# data\genres\blues\blues.00068.au
# data\genres\blues\blues.00069.au
# data\genres\blues\blues.00070.au
# data\genres\blues\blues.00071.au
# data\genres\blues\blues.00072.au
# data\genres\blues\blues.00073.au
# data\genres\blues\blues.00074.au
# data\genres\blues\blues.00075.au
# data\genres\blues\blues.00076.au
# data\genres\blues\blues.00077.au
# data\genres\blues\blues.00078.au
# data\genres\blues\blues.00079.au
# data\genres\blues\blues.00080.au
# data\genres\blues\blues.00081.au
# data\genres\blues\blues.00082.au
# data\genres\blues\blues.00083.au
# data\genres\blues\blues.00084.au
# data\genres\blues\blues.00085.au
# data\genres\blues\blues.00086.au
# data\genres\blues\blues.00087.au
# data\genres\blues\blues.00088.au
# data\genres\blues\blues.00089.au
# data\genres\blues\blues.00090.au
# data\genres\blues\blues.00091.au
# data\genres\blues\blues.00092.au
# data\genres\blues\blues.00093.au
# data\genres\blues\blues.00094.au
# data\genres\blues\blues.00095.au
# data\genres\blues\blues.00096.au
# data\genres\blues\blues.00097.au
# data\genres\blues\blues.00098.au
# data\genres\blues\blues.00099.au
# data\genres\classical\classical.00000.au
# data\genres\classical\classical.00001.au
# data\genres\classical\classical.00002.au
# data\genres\classical\classical.00003.au
# data\genres\classical\classical.00004.au
# data\genres\classical\classical.00005.au
# data\genres\classical\classical.00006.au
# data\genres\classical\classical.00007.au
# data\genres\classical\classical.00008.au
# data\genres\classical\classical.00009.au
# data\genres\classical\classical.00010.au
# data\genres\classical\classical.00011.au
# data\genres\classical\classical.00012.au
# data\genres\classical\classical.00013.au
# data\genres\classical\classical.00014.au
# data\genres\classical\classical.00015.au
# data\genres\classical\classical.00016.au
# data\genres\classical\classical.00017.au
# data\genres\classical\classical.00018.au
# data\genres\classical\classical.00019.au
# data\genres\classical\classical.00020.au
# data\genres\classical\classical.00021.au
# data\genres\classical\classical.00022.au
# data\genres\classical\classical.00023.au
# data\genres\classical\classical.00024.au
# data\genres\classical\classical.00025.au
# data\genres\classical\classical.00026.au
# data\genres\classical\classical.00027.au
# data\genres\classical\classical.00028.au
# data\genres\classical\classical.00029.au
# data\genres\classical\classical.00030.au
# data\genres\classical\classical.00031.au
# data\genres\classical\classical.00032.au
# data\genres\classical\classical.00033.au
# data\genres\classical\classical.00034.au
# data\genres\classical\classical.00035.au
# data\genres\classical\classical.00036.au
# data\genres\classical\classical.00037.au
# data\genres\classical\classical.00038.au
# data\genres\classical\classical.00039.au
# data\genres\classical\classical.00040.au
# data\genres\classical\classical.00041.au
# data\genres\classical\classical.00042.au
# data\genres\classical\classical.00043.au
# data\genres\classical\classical.00044.au
# data\genres\classical\classical.00045.au
# data\genres\classical\classical.00046.au
# data\genres\classical\classical.00047.au
# data\genres\classical\classical.00048.au
# data\genres\classical\classical.00049.au
# data\genres\classical\classical.00050.au
# data\genres\classical\classical.00051.au
# data\genres\classical\classical.00052.au
# data\genres\classical\classical.00053.au
# data\genres\classical\classical.00054.au
# data\genres\classical\classical.00055.au
# data\genres\classical\classical.00056.au
# data\genres\classical\classical.00057.au
# data\genres\classical\classical.00058.au
# data\genres\classical\classical.00059.au
# data\genres\classical\classical.00060.au
# data\genres\classical\classical.00061.au
# data\genres\classical\classical.00062.au
# data\genres\classical\classical.00063.au
# data\genres\classical\classical.00064.au
# data\genres\classical\classical.00065.au
# data\genres\classical\classical.00066.au
# data\genres\classical\classical.00067.au
# data\genres\classical\classical.00068.au
# data\genres\classical\classical.00069.au
# data\genres\classical\classical.00070.au
# data\genres\classical\classical.00071.au
# data\genres\classical\classical.00072.au
# data\genres\classical\classical.00073.au
# data\genres\classical\classical.00074.au
# data\genres\classical\classical.00075.au
# data\genres\classical\classical.00076.au
# data\genres\classical\classical.00077.au
# data\genres\classical\classical.00078.au
# data\genres\classical\classical.00079.au
# data\genres\classical\classical.00080.au
# data\genres\classical\classical.00081.au
# data\genres\classical\classical.00082.au
# data\genres\classical\classical.00083.au
# data\genres\classical\classical.00084.au
# data\genres\classical\classical.00085.au
# data\genres\classical\classical.00086.au
# data\genres\classical\classical.00087.au
# data\genres\classical\classical.00088.au
# data\genres\classical\classical.00089.au
# data\genres\classical\classical.00090.au
# data\genres\classical\classical.00091.au
# data\genres\classical\classical.00092.au
# data\genres\classical\classical.00093.au
# data\genres\classical\classical.00094.au
# data\genres\classical\classical.00095.au
# data\genres\classical\classical.00096.au
# data\genres\classical\classical.00097.au
# data\genres\classical\classical.00098.au
# data\genres\classical\classical.00099.au
# data\genres\country\country.00000.au
# data\genres\country\country.00001.au
# data\genres\country\country.00002.au
# data\genres\country\country.00003.au
# data\genres\country\country.00004.au
# data\genres\country\country.00005.au
# data\genres\country\country.00006.au
# data\genres\country\country.00007.au
# data\genres\country\country.00008.au
# data\genres\country\country.00009.au
# data\genres\country\country.00010.au
# data\genres\country\country.00011.au
# data\genres\country\country.00012.au
# data\genres\country\country.00013.au
# data\genres\country\country.00014.au
# data\genres\country\country.00015.au
# data\genres\country\country.00016.au
# data\genres\country\country.00017.au
# data\genres\country\country.00018.au
# data\genres\country\country.00019.au
# data\genres\country\country.00020.au
# data\genres\country\country.00021.au
# data\genres\country\country.00022.au
# data\genres\country\country.00023.au
# data\genres\country\country.00024.au
# data\genres\country\country.00025.au
# data\genres\country\country.00026.au
# data\genres\country\country.00027.au
# data\genres\country\country.00028.au
# data\genres\country\country.00029.au
# data\genres\country\country.00030.au
# data\genres\country\country.00031.au
# data\genres\country\country.00032.au
# data\genres\country\country.00033.au
# data\genres\country\country.00034.au
# data\genres\country\country.00035.au
# data\genres\country\country.00036.au
# data\genres\country\country.00037.au
# data\genres\country\country.00038.au
# data\genres\country\country.00039.au
# data\genres\country\country.00040.au
# data\genres\country\country.00041.au
# data\genres\country\country.00042.au
# data\genres\country\country.00043.au
# data\genres\country\country.00044.au
# data\genres\country\country.00045.au
# data\genres\country\country.00046.au
# data\genres\country\country.00047.au
# data\genres\country\country.00048.au
# data\genres\country\country.00049.au
# data\genres\country\country.00050.au
# data\genres\country\country.00051.au
# data\genres\country\country.00052.au
# data\genres\country\country.00053.au
# data\genres\country\country.00054.au
# data\genres\country\country.00055.au
# data\genres\country\country.00056.au
# data\genres\country\country.00057.au
# data\genres\country\country.00058.au
# data\genres\country\country.00059.au
# data\genres\country\country.00060.au
# data\genres\country\country.00061.au
# data\genres\country\country.00062.au
# data\genres\country\country.00063.au
# data\genres\country\country.00064.au
# data\genres\country\country.00065.au
# data\genres\country\country.00066.au
# data\genres\country\country.00067.au
# data\genres\country\country.00068.au
# data\genres\country\country.00069.au
# data\genres\country\country.00070.au
# data\genres\country\country.00071.au
# data\genres\country\country.00072.au
# data\genres\country\country.00073.au
# data\genres\country\country.00074.au
# data\genres\country\country.00075.au
# data\genres\country\country.00076.au
# data\genres\country\country.00077.au
# data\genres\country\country.00078.au
# data\genres\country\country.00079.au
# data\genres\country\country.00080.au
# data\genres\country\country.00081.au
# data\genres\country\country.00082.au
# data\genres\country\country.00083.au
# data\genres\country\country.00084.au
# data\genres\country\country.00085.au
# data\genres\country\country.00086.au
# data\genres\country\country.00087.au
# data\genres\country\country.00088.au
# data\genres\country\country.00089.au
# data\genres\country\country.00090.au
# data\genres\country\country.00091.au
# data\genres\country\country.00092.au
# data\genres\country\country.00093.au
# data\genres\country\country.00094.au
# data\genres\country\country.00095.au
# data\genres\country\country.00096.au
# data\genres\country\country.00097.au
# data\genres\country\country.00098.au
# data\genres\country\country.00099.au
# data\genres\disco\disco.00000.au
# data\genres\disco\disco.00001.au
# data\genres\disco\disco.00002.au
# data\genres\disco\disco.00003.au
# data\genres\disco\disco.00004.au
# data\genres\disco\disco.00005.au
# data\genres\disco\disco.00006.au
# data\genres\disco\disco.00007.au
# data\genres\disco\disco.00008.au
# data\genres\disco\disco.00009.au
# data\genres\disco\disco.00010.au
# data\genres\disco\disco.00011.au
# data\genres\disco\disco.00012.au
# data\genres\disco\disco.00013.au
# data\genres\disco\disco.00014.au
# data\genres\disco\disco.00015.au
# data\genres\disco\disco.00016.au
# data\genres\disco\disco.00017.au
# data\genres\disco\disco.00018.au
# data\genres\disco\disco.00019.au
# data\genres\disco\disco.00020.au
# data\genres\disco\disco.00021.au
# data\genres\disco\disco.00022.au
# data\genres\disco\disco.00023.au
# data\genres\disco\disco.00024.au
# data\genres\disco\disco.00025.au
# data\genres\disco\disco.00026.au
# data\genres\disco\disco.00027.au
# data\genres\disco\disco.00028.au
# data\genres\disco\disco.00029.au
# data\genres\disco\disco.00030.au
# data\genres\disco\disco.00031.au
# data\genres\disco\disco.00032.au
# data\genres\disco\disco.00033.au
# data\genres\disco\disco.00034.au
# data\genres\disco\disco.00035.au
# data\genres\disco\disco.00036.au
# data\genres\disco\disco.00037.au
# data\genres\disco\disco.00038.au
# data\genres\disco\disco.00039.au
# data\genres\disco\disco.00040.au
# data\genres\disco\disco.00041.au
# data\genres\disco\disco.00042.au
# data\genres\disco\disco.00043.au
# data\genres\disco\disco.00044.au
# data\genres\disco\disco.00045.au
# data\genres\disco\disco.00046.au
# data\genres\disco\disco.00047.au
# data\genres\disco\disco.00048.au
# data\genres\disco\disco.00049.au
# data\genres\disco\disco.00050.au
# data\genres\disco\disco.00051.au
# data\genres\disco\disco.00052.au
# data\genres\disco\disco.00053.au
# data\genres\disco\disco.00054.au
# data\genres\disco\disco.00055.au
# data\genres\disco\disco.00056.au
# data\genres\disco\disco.00057.au
# data\genres\disco\disco.00058.au
# data\genres\disco\disco.00059.au
# data\genres\disco\disco.00060.au
# data\genres\disco\disco.00061.au
# data\genres\disco\disco.00062.au
# data\genres\disco\disco.00063.au
# data\genres\disco\disco.00064.au
# data\genres\disco\disco.00065.au
# data\genres\disco\disco.00066.au
# data\genres\disco\disco.00067.au
# data\genres\disco\disco.00068.au
# data\genres\disco\disco.00069.au
# data\genres\disco\disco.00070.au
# data\genres\disco\disco.00071.au
# data\genres\disco\disco.00072.au
# data\genres\disco\disco.00073.au
# data\genres\disco\disco.00074.au
# data\genres\disco\disco.00075.au
# data\genres\disco\disco.00076.au
# data\genres\disco\disco.00077.au
# data\genres\disco\disco.00078.au
# data\genres\disco\disco.00079.au
# data\genres\disco\disco.00080.au
# data\genres\disco\disco.00081.au
# data\genres\disco\disco.00082.au
# data\genres\disco\disco.00083.au
# data\genres\disco\disco.00084.au
# data\genres\disco\disco.00085.au
# data\genres\disco\disco.00086.au
# data\genres\disco\disco.00087.au
# data\genres\disco\disco.00088.au
# data\genres\disco\disco.00089.au
# data\genres\disco\disco.00090.au
# data\genres\disco\disco.00091.au
# data\genres\disco\disco.00092.au
# data\genres\disco\disco.00093.au
# data\genres\disco\disco.00094.au
# data\genres\disco\disco.00095.au
# data\genres\disco\disco.00096.au
# data\genres\disco\disco.00097.au
# data\genres\disco\disco.00098.au
# data\genres\disco\disco.00099.au
# data\genres\hiphop\hiphop.00000.au
# data\genres\hiphop\hiphop.00001.au
# data\genres\hiphop\hiphop.00002.au
# data\genres\hiphop\hiphop.00003.au
# data\genres\hiphop\hiphop.00004.au
# data\genres\hiphop\hiphop.00005.au
# data\genres\hiphop\hiphop.00006.au
# data\genres\hiphop\hiphop.00007.au
# data\genres\hiphop\hiphop.00008.au
# data\genres\hiphop\hiphop.00009.au
# data\genres\hiphop\hiphop.00010.au
# data\genres\hiphop\hiphop.00011.au
# data\genres\hiphop\hiphop.00012.au
# data\genres\hiphop\hiphop.00013.au
# data\genres\hiphop\hiphop.00014.au
# data\genres\hiphop\hiphop.00015.au
# data\genres\hiphop\hiphop.00016.au
# data\genres\hiphop\hiphop.00017.au
# data\genres\hiphop\hiphop.00018.au
# data\genres\hiphop\hiphop.00019.au
# data\genres\hiphop\hiphop.00020.au
# data\genres\hiphop\hiphop.00021.au
# data\genres\hiphop\hiphop.00022.au
# data\genres\hiphop\hiphop.00023.au
# data\genres\hiphop\hiphop.00024.au
# data\genres\hiphop\hiphop.00025.au
# data\genres\hiphop\hiphop.00026.au
# data\genres\hiphop\hiphop.00027.au
# data\genres\hiphop\hiphop.00028.au
# data\genres\hiphop\hiphop.00029.au
# data\genres\hiphop\hiphop.00030.au
# data\genres\hiphop\hiphop.00031.au
# data\genres\hiphop\hiphop.00032.au
# data\genres\hiphop\hiphop.00033.au
# data\genres\hiphop\hiphop.00034.au
# data\genres\hiphop\hiphop.00035.au
# data\genres\hiphop\hiphop.00036.au
# data\genres\hiphop\hiphop.00037.au
# data\genres\hiphop\hiphop.00038.au
# data\genres\hiphop\hiphop.00039.au
# data\genres\hiphop\hiphop.00040.au
# data\genres\hiphop\hiphop.00041.au
# data\genres\hiphop\hiphop.00042.au
# data\genres\hiphop\hiphop.00043.au
# data\genres\hiphop\hiphop.00044.au
# data\genres\hiphop\hiphop.00045.au
# data\genres\hiphop\hiphop.00046.au
# data\genres\hiphop\hiphop.00047.au
# data\genres\hiphop\hiphop.00048.au
# data\genres\hiphop\hiphop.00049.au
# data\genres\hiphop\hiphop.00050.au
# data\genres\hiphop\hiphop.00051.au
# data\genres\hiphop\hiphop.00052.au
# data\genres\hiphop\hiphop.00053.au
# data\genres\hiphop\hiphop.00054.au
# data\genres\hiphop\hiphop.00055.au
# data\genres\hiphop\hiphop.00056.au
# data\genres\hiphop\hiphop.00057.au
# data\genres\hiphop\hiphop.00058.au
# data\genres\hiphop\hiphop.00059.au
# data\genres\hiphop\hiphop.00060.au
# data\genres\hiphop\hiphop.00061.au
# data\genres\hiphop\hiphop.00062.au
# data\genres\hiphop\hiphop.00063.au
# data\genres\hiphop\hiphop.00064.au
# data\genres\hiphop\hiphop.00065.au
# data\genres\hiphop\hiphop.00066.au
# data\genres\hiphop\hiphop.00067.au
# data\genres\hiphop\hiphop.00068.au
# data\genres\hiphop\hiphop.00069.au
# data\genres\hiphop\hiphop.00070.au
# data\genres\hiphop\hiphop.00071.au
# data\genres\hiphop\hiphop.00072.au
# data\genres\hiphop\hiphop.00073.au
# data\genres\hiphop\hiphop.00074.au
# data\genres\hiphop\hiphop.00075.au
# data\genres\hiphop\hiphop.00076.au
# data\genres\hiphop\hiphop.00077.au
# data\genres\hiphop\hiphop.00078.au
# data\genres\hiphop\hiphop.00079.au
# data\genres\hiphop\hiphop.00080.au
# data\genres\hiphop\hiphop.00081.au
# data\genres\hiphop\hiphop.00082.au
# data\genres\hiphop\hiphop.00083.au
# data\genres\hiphop\hiphop.00084.au
# data\genres\hiphop\hiphop.00085.au
# data\genres\hiphop\hiphop.00086.au
# data\genres\hiphop\hiphop.00087.au
# data\genres\hiphop\hiphop.00088.au
# data\genres\hiphop\hiphop.00089.au
# data\genres\hiphop\hiphop.00090.au
# data\genres\hiphop\hiphop.00091.au
# data\genres\hiphop\hiphop.00092.au
# data\genres\hiphop\hiphop.00093.au
# data\genres\hiphop\hiphop.00094.au
# data\genres\hiphop\hiphop.00095.au
# data\genres\hiphop\hiphop.00096.au
# data\genres\hiphop\hiphop.00097.au
# data\genres\hiphop\hiphop.00098.au
# data\genres\hiphop\hiphop.00099.au
# data\genres\jazz\jazz.00000.au
# data\genres\jazz\jazz.00001.au
# data\genres\jazz\jazz.00002.au
# data\genres\jazz\jazz.00003.au
# data\genres\jazz\jazz.00004.au
# data\genres\jazz\jazz.00005.au
# data\genres\jazz\jazz.00006.au
# data\genres\jazz\jazz.00007.au
# data\genres\jazz\jazz.00008.au
# data\genres\jazz\jazz.00009.au
# data\genres\jazz\jazz.00010.au
# data\genres\jazz\jazz.00011.au
# data\genres\jazz\jazz.00012.au
# data\genres\jazz\jazz.00013.au
# data\genres\jazz\jazz.00014.au
# data\genres\jazz\jazz.00015.au
# data\genres\jazz\jazz.00016.au
# data\genres\jazz\jazz.00017.au
# data\genres\jazz\jazz.00018.au
# data\genres\jazz\jazz.00019.au
# data\genres\jazz\jazz.00020.au
# data\genres\jazz\jazz.00021.au
# data\genres\jazz\jazz.00022.au
# data\genres\jazz\jazz.00023.au
# data\genres\jazz\jazz.00024.au
# data\genres\jazz\jazz.00025.au
# data\genres\jazz\jazz.00026.au
# data\genres\jazz\jazz.00027.au
# data\genres\jazz\jazz.00028.au
# data\genres\jazz\jazz.00029.au
# data\genres\jazz\jazz.00030.au
# data\genres\jazz\jazz.00031.au
# data\genres\jazz\jazz.00032.au
# data\genres\jazz\jazz.00033.au
# data\genres\jazz\jazz.00034.au
# data\genres\jazz\jazz.00035.au
# data\genres\jazz\jazz.00036.au
# data\genres\jazz\jazz.00037.au
# data\genres\jazz\jazz.00038.au
# data\genres\jazz\jazz.00039.au
# data\genres\jazz\jazz.00040.au
# data\genres\jazz\jazz.00041.au
# data\genres\jazz\jazz.00042.au
# data\genres\jazz\jazz.00043.au
# data\genres\jazz\jazz.00044.au
# data\genres\jazz\jazz.00045.au
# data\genres\jazz\jazz.00046.au
# data\genres\jazz\jazz.00047.au
# data\genres\jazz\jazz.00048.au
# data\genres\jazz\jazz.00049.au
# data\genres\jazz\jazz.00050.au
# data\genres\jazz\jazz.00051.au
# data\genres\jazz\jazz.00052.au
# data\genres\jazz\jazz.00053.au
# data\genres\jazz\jazz.00054.au
# data\genres\jazz\jazz.00055.au
# data\genres\jazz\jazz.00056.au
# data\genres\jazz\jazz.00057.au
# data\genres\jazz\jazz.00058.au
# data\genres\jazz\jazz.00059.au
# data\genres\jazz\jazz.00060.au
# data\genres\jazz\jazz.00061.au
# data\genres\jazz\jazz.00062.au
# data\genres\jazz\jazz.00063.au
# data\genres\jazz\jazz.00064.au
# data\genres\jazz\jazz.00065.au
# data\genres\jazz\jazz.00066.au
# data\genres\jazz\jazz.00067.au
# data\genres\jazz\jazz.00068.au
# data\genres\jazz\jazz.00069.au
# data\genres\jazz\jazz.00070.au
# data\genres\jazz\jazz.00071.au
# data\genres\jazz\jazz.00072.au
# data\genres\jazz\jazz.00073.au
# data\genres\jazz\jazz.00074.au
# data\genres\jazz\jazz.00075.au
# data\genres\jazz\jazz.00076.au
# data\genres\jazz\jazz.00077.au
# data\genres\jazz\jazz.00078.au
# data\genres\jazz\jazz.00079.au
# data\genres\jazz\jazz.00080.au
# data\genres\jazz\jazz.00081.au
# data\genres\jazz\jazz.00082.au
# data\genres\jazz\jazz.00083.au
# data\genres\jazz\jazz.00084.au
# data\genres\jazz\jazz.00085.au
# data\genres\jazz\jazz.00086.au
# data\genres\jazz\jazz.00087.au
# data\genres\jazz\jazz.00088.au
# data\genres\jazz\jazz.00089.au
# data\genres\jazz\jazz.00090.au
# data\genres\jazz\jazz.00091.au
# data\genres\jazz\jazz.00092.au
# data\genres\jazz\jazz.00093.au
# data\genres\jazz\jazz.00094.au
# data\genres\jazz\jazz.00095.au
# data\genres\jazz\jazz.00096.au
# data\genres\jazz\jazz.00097.au
# data\genres\jazz\jazz.00098.au
# data\genres\jazz\jazz.00099.au
# data\genres\metal\metal.00000.au
# data\genres\metal\metal.00001.au
# data\genres\metal\metal.00002.au
# data\genres\metal\metal.00003.au
# data\genres\metal\metal.00004.au
# data\genres\metal\metal.00005.au
# data\genres\metal\metal.00006.au
# data\genres\metal\metal.00007.au
# data\genres\metal\metal.00008.au
# data\genres\metal\metal.00009.au
# data\genres\metal\metal.00010.au
# data\genres\metal\metal.00011.au
# data\genres\metal\metal.00012.au
# data\genres\metal\metal.00013.au
# data\genres\metal\metal.00014.au
# data\genres\metal\metal.00015.au
# data\genres\metal\metal.00016.au
# data\genres\metal\metal.00017.au
# data\genres\metal\metal.00018.au
# data\genres\metal\metal.00019.au
# data\genres\metal\metal.00020.au
# data\genres\metal\metal.00021.au
# data\genres\metal\metal.00022.au
# data\genres\metal\metal.00023.au
# data\genres\metal\metal.00024.au
# data\genres\metal\metal.00025.au
# data\genres\metal\metal.00026.au
# data\genres\metal\metal.00027.au
# data\genres\metal\metal.00028.au
# data\genres\metal\metal.00029.au
# data\genres\metal\metal.00030.au
# data\genres\metal\metal.00031.au
# data\genres\metal\metal.00032.au
# data\genres\metal\metal.00033.au
# data\genres\metal\metal.00034.au
# data\genres\metal\metal.00035.au
# data\genres\metal\metal.00036.au
# data\genres\metal\metal.00037.au
# data\genres\metal\metal.00038.au
# data\genres\metal\metal.00039.au
# data\genres\metal\metal.00040.au
# data\genres\metal\metal.00041.au
# data\genres\metal\metal.00042.au
# data\genres\metal\metal.00043.au
# data\genres\metal\metal.00044.au
# data\genres\metal\metal.00045.au
# data\genres\metal\metal.00046.au
# data\genres\metal\metal.00047.au
# data\genres\metal\metal.00048.au
# data\genres\metal\metal.00049.au
# data\genres\metal\metal.00050.au
# data\genres\metal\metal.00051.au
# data\genres\metal\metal.00052.au
# data\genres\metal\metal.00053.au
# data\genres\metal\metal.00054.au
# data\genres\metal\metal.00055.au
# data\genres\metal\metal.00056.au
# data\genres\metal\metal.00057.au
# data\genres\metal\metal.00058.au
# data\genres\metal\metal.00059.au
# data\genres\metal\metal.00060.au
# data\genres\metal\metal.00061.au
# data\genres\metal\metal.00062.au
# data\genres\metal\metal.00063.au
# data\genres\metal\metal.00064.au
# data\genres\metal\metal.00065.au
# data\genres\metal\metal.00066.au
# data\genres\metal\metal.00067.au
# data\genres\metal\metal.00068.au
# data\genres\metal\metal.00069.au
# data\genres\metal\metal.00070.au
# data\genres\metal\metal.00071.au
# data\genres\metal\metal.00072.au
# data\genres\metal\metal.00073.au
# data\genres\metal\metal.00074.au
# data\genres\metal\metal.00075.au
# data\genres\metal\metal.00076.au
# data\genres\metal\metal.00077.au
# data\genres\metal\metal.00078.au
# data\genres\metal\metal.00079.au
# data\genres\metal\metal.00080.au
# data\genres\metal\metal.00081.au
# data\genres\metal\metal.00082.au
# data\genres\metal\metal.00083.au
# data\genres\metal\metal.00084.au
# data\genres\metal\metal.00085.au
# data\genres\metal\metal.00086.au
# data\genres\metal\metal.00087.au
# data\genres\metal\metal.00088.au
# data\genres\metal\metal.00089.au
# data\genres\metal\metal.00090.au
# data\genres\metal\metal.00091.au
# data\genres\metal\metal.00092.au
# data\genres\metal\metal.00093.au
# data\genres\metal\metal.00094.au
# data\genres\metal\metal.00095.au
# data\genres\metal\metal.00096.au
# data\genres\metal\metal.00097.au
# data\genres\metal\metal.00098.au
# data\genres\metal\metal.00099.au
# data\genres\pop\pop.00000.au
# data\genres\pop\pop.00001.au
# data\genres\pop\pop.00002.au
# data\genres\pop\pop.00003.au
# data\genres\pop\pop.00004.au
# data\genres\pop\pop.00005.au
# data\genres\pop\pop.00006.au
# data\genres\pop\pop.00007.au
# data\genres\pop\pop.00008.au
# data\genres\pop\pop.00009.au
# data\genres\pop\pop.00010.au
# data\genres\pop\pop.00011.au
# data\genres\pop\pop.00012.au
# data\genres\pop\pop.00013.au
# data\genres\pop\pop.00014.au
# data\genres\pop\pop.00015.au
# data\genres\pop\pop.00016.au
# data\genres\pop\pop.00017.au
# data\genres\pop\pop.00018.au
# data\genres\pop\pop.00019.au
# data\genres\pop\pop.00020.au
# data\genres\pop\pop.00021.au
# data\genres\pop\pop.00022.au
# data\genres\pop\pop.00023.au
# data\genres\pop\pop.00024.au
# data\genres\pop\pop.00025.au
# data\genres\pop\pop.00026.au
# data\genres\pop\pop.00027.au
# data\genres\pop\pop.00028.au
# data\genres\pop\pop.00029.au
# data\genres\pop\pop.00030.au
# data\genres\pop\pop.00031.au
# data\genres\pop\pop.00032.au
# data\genres\pop\pop.00033.au
# data\genres\pop\pop.00034.au
# data\genres\pop\pop.00035.au
# data\genres\pop\pop.00036.au
# data\genres\pop\pop.00037.au
# data\genres\pop\pop.00038.au
# data\genres\pop\pop.00039.au
# data\genres\pop\pop.00040.au
# data\genres\pop\pop.00041.au
# data\genres\pop\pop.00042.au
# data\genres\pop\pop.00043.au
# data\genres\pop\pop.00044.au
# data\genres\pop\pop.00045.au
# data\genres\pop\pop.00046.au
# data\genres\pop\pop.00047.au
# data\genres\pop\pop.00048.au
# data\genres\pop\pop.00049.au
# data\genres\pop\pop.00050.au
# data\genres\pop\pop.00051.au
# data\genres\pop\pop.00052.au
# data\genres\pop\pop.00053.au
# data\genres\pop\pop.00054.au
# data\genres\pop\pop.00055.au
# data\genres\pop\pop.00056.au
# data\genres\pop\pop.00057.au
# data\genres\pop\pop.00058.au
# data\genres\pop\pop.00059.au
# data\genres\pop\pop.00060.au
# data\genres\pop\pop.00061.au
# data\genres\pop\pop.00062.au
# data\genres\pop\pop.00063.au
# data\genres\pop\pop.00064.au
# data\genres\pop\pop.00065.au
# data\genres\pop\pop.00066.au
# data\genres\pop\pop.00067.au
# data\genres\pop\pop.00068.au
# data\genres\pop\pop.00069.au
# data\genres\pop\pop.00070.au
# data\genres\pop\pop.00071.au
# data\genres\pop\pop.00072.au
# data\genres\pop\pop.00073.au
# data\genres\pop\pop.00074.au
# data\genres\pop\pop.00075.au
# data\genres\pop\pop.00076.au
# data\genres\pop\pop.00077.au
# data\genres\pop\pop.00078.au
# data\genres\pop\pop.00079.au
# data\genres\pop\pop.00080.au
# data\genres\pop\pop.00081.au
# data\genres\pop\pop.00082.au
# data\genres\pop\pop.00083.au
# data\genres\pop\pop.00084.au
# data\genres\pop\pop.00085.au
# data\genres\pop\pop.00086.au
# data\genres\pop\pop.00087.au
# data\genres\pop\pop.00088.au
# data\genres\pop\pop.00089.au
# data\genres\pop\pop.00090.au
# data\genres\pop\pop.00091.au
# data\genres\pop\pop.00092.au
# data\genres\pop\pop.00093.au
# data\genres\pop\pop.00094.au
# data\genres\pop\pop.00095.au
# data\genres\pop\pop.00096.au
# data\genres\pop\pop.00097.au
# data\genres\pop\pop.00098.au
# data\genres\pop\pop.00099.au
# data\genres\reggae\reggae.00000.au
# data\genres\reggae\reggae.00001.au
# data\genres\reggae\reggae.00002.au
# data\genres\reggae\reggae.00003.au
# data\genres\reggae\reggae.00004.au
# data\genres\reggae\reggae.00005.au
# data\genres\reggae\reggae.00006.au
# data\genres\reggae\reggae.00007.au
# data\genres\reggae\reggae.00008.au
# data\genres\reggae\reggae.00009.au
# data\genres\reggae\reggae.00010.au
# data\genres\reggae\reggae.00011.au
# data\genres\reggae\reggae.00012.au
# data\genres\reggae\reggae.00013.au
# data\genres\reggae\reggae.00014.au
# data\genres\reggae\reggae.00015.au
# data\genres\reggae\reggae.00016.au
# data\genres\reggae\reggae.00017.au
# data\genres\reggae\reggae.00018.au
# data\genres\reggae\reggae.00019.au
# data\genres\reggae\reggae.00020.au
# data\genres\reggae\reggae.00021.au
# data\genres\reggae\reggae.00022.au
# data\genres\reggae\reggae.00023.au
# data\genres\reggae\reggae.00024.au
# data\genres\reggae\reggae.00025.au
# data\genres\reggae\reggae.00026.au
# data\genres\reggae\reggae.00027.au
# data\genres\reggae\reggae.00028.au
# data\genres\reggae\reggae.00029.au
# data\genres\reggae\reggae.00030.au
# data\genres\reggae\reggae.00031.au
# data\genres\reggae\reggae.00032.au
# data\genres\reggae\reggae.00033.au
# data\genres\reggae\reggae.00034.au
# data\genres\reggae\reggae.00035.au
# data\genres\reggae\reggae.00036.au
# data\genres\reggae\reggae.00037.au
# data\genres\reggae\reggae.00038.au
# data\genres\reggae\reggae.00039.au
# data\genres\reggae\reggae.00040.au
# data\genres\reggae\reggae.00041.au
# data\genres\reggae\reggae.00042.au
# data\genres\reggae\reggae.00043.au
# data\genres\reggae\reggae.00044.au
# data\genres\reggae\reggae.00045.au
# data\genres\reggae\reggae.00046.au
# data\genres\reggae\reggae.00047.au
# data\genres\reggae\reggae.00048.au
# data\genres\reggae\reggae.00049.au
# data\genres\reggae\reggae.00050.au
# data\genres\reggae\reggae.00051.au
# data\genres\reggae\reggae.00052.au
# data\genres\reggae\reggae.00053.au
# data\genres\reggae\reggae.00054.au
# data\genres\reggae\reggae.00055.au
# data\genres\reggae\reggae.00056.au
# data\genres\reggae\reggae.00057.au
# data\genres\reggae\reggae.00058.au
# data\genres\reggae\reggae.00059.au
# data\genres\reggae\reggae.00060.au
# data\genres\reggae\reggae.00061.au
# data\genres\reggae\reggae.00062.au
# data\genres\reggae\reggae.00063.au
# data\genres\reggae\reggae.00064.au
# data\genres\reggae\reggae.00065.au
# data\genres\reggae\reggae.00066.au
# data\genres\reggae\reggae.00067.au
# data\genres\reggae\reggae.00068.au
# data\genres\reggae\reggae.00069.au
# data\genres\reggae\reggae.00070.au
# data\genres\reggae\reggae.00071.au
# data\genres\reggae\reggae.00072.au
# data\genres\reggae\reggae.00073.au
# data\genres\reggae\reggae.00074.au
# data\genres\reggae\reggae.00075.au
# data\genres\reggae\reggae.00076.au
# data\genres\reggae\reggae.00077.au
# data\genres\reggae\reggae.00078.au
# data\genres\reggae\reggae.00079.au
# data\genres\reggae\reggae.00080.au
# data\genres\reggae\reggae.00081.au
# data\genres\reggae\reggae.00082.au
# data\genres\reggae\reggae.00083.au
# data\genres\reggae\reggae.00084.au
# data\genres\reggae\reggae.00085.au
# data\genres\reggae\reggae.00086.au
# data\genres\reggae\reggae.00087.au
# data\genres\reggae\reggae.00088.au
# data\genres\reggae\reggae.00089.au
# data\genres\reggae\reggae.00090.au
# data\genres\reggae\reggae.00091.au
# data\genres\reggae\reggae.00092.au
# data\genres\reggae\reggae.00093.au
# data\genres\reggae\reggae.00094.au
# data\genres\reggae\reggae.00095.au
# data\genres\reggae\reggae.00096.au
# data\genres\reggae\reggae.00097.au
# data\genres\reggae\reggae.00098.au
# data\genres\reggae\reggae.00099.au
# data\genres\rock\rock.00000.au
# data\genres\rock\rock.00001.au
# data\genres\rock\rock.00002.au
# data\genres\rock\rock.00003.au
# data\genres\rock\rock.00004.au
# data\genres\rock\rock.00005.au
# data\genres\rock\rock.00006.au
# data\genres\rock\rock.00007.au
# data\genres\rock\rock.00008.au
# data\genres\rock\rock.00009.au
# data\genres\rock\rock.00010.au
# data\genres\rock\rock.00011.au
# data\genres\rock\rock.00012.au
# data\genres\rock\rock.00013.au
# data\genres\rock\rock.00014.au
# data\genres\rock\rock.00015.au
# data\genres\rock\rock.00016.au
# data\genres\rock\rock.00017.au
# data\genres\rock\rock.00018.au
# data\genres\rock\rock.00019.au
# data\genres\rock\rock.00020.au
# data\genres\rock\rock.00021.au
# data\genres\rock\rock.00022.au
# data\genres\rock\rock.00023.au
# data\genres\rock\rock.00024.au
# data\genres\rock\rock.00025.au
# data\genres\rock\rock.00026.au
# data\genres\rock\rock.00027.au
# data\genres\rock\rock.00028.au
# data\genres\rock\rock.00029.au
# data\genres\rock\rock.00030.au
# data\genres\rock\rock.00031.au
# data\genres\rock\rock.00032.au
# data\genres\rock\rock.00033.au
# data\genres\rock\rock.00034.au
# data\genres\rock\rock.00035.au
# data\genres\rock\rock.00036.au
# data\genres\rock\rock.00037.au
# data\genres\rock\rock.00038.au
# data\genres\rock\rock.00039.au
# data\genres\rock\rock.00040.au
# data\genres\rock\rock.00041.au
# data\genres\rock\rock.00042.au
# data\genres\rock\rock.00043.au
# data\genres\rock\rock.00044.au
# data\genres\rock\rock.00045.au
# data\genres\rock\rock.00046.au
# data\genres\rock\rock.00047.au
# data\genres\rock\rock.00048.au
# data\genres\rock\rock.00049.au
# data\genres\rock\rock.00050.au
# data\genres\rock\rock.00051.au
# data\genres\rock\rock.00052.au
# data\genres\rock\rock.00053.au
# data\genres\rock\rock.00054.au
# data\genres\rock\rock.00055.au
# data\genres\rock\rock.00056.au
# data\genres\rock\rock.00057.au
# data\genres\rock\rock.00058.au
# data\genres\rock\rock.00059.au
# data\genres\rock\rock.00060.au
# data\genres\rock\rock.00061.au
# data\genres\rock\rock.00062.au
# data\genres\rock\rock.00063.au
# data\genres\rock\rock.00064.au
# data\genres\rock\rock.00065.au
# data\genres\rock\rock.00066.au
# data\genres\rock\rock.00067.au
# data\genres\rock\rock.00068.au
# data\genres\rock\rock.00069.au
# data\genres\rock\rock.00070.au
# data\genres\rock\rock.00071.au
# data\genres\rock\rock.00072.au
# data\genres\rock\rock.00073.au
# data\genres\rock\rock.00074.au
# data\genres\rock\rock.00075.au
# data\genres\rock\rock.00076.au
# data\genres\rock\rock.00077.au
# data\genres\rock\rock.00078.au
# data\genres\rock\rock.00079.au
# data\genres\rock\rock.00080.au
# data\genres\rock\rock.00081.au
# data\genres\rock\rock.00082.au
# data\genres\rock\rock.00083.au
# data\genres\rock\rock.00084.au
# data\genres\rock\rock.00085.au
# data\genres\rock\rock.00086.au
# data\genres\rock\rock.00087.au
# data\genres\rock\rock.00088.au
# data\genres\rock\rock.00089.au
# data\genres\rock\rock.00090.au
# data\genres\rock\rock.00091.au
# data\genres\rock\rock.00092.au
# data\genres\rock\rock.00093.au
# data\genres\rock\rock.00094.au
# data\genres\rock\rock.00095.au
# data\genres\rock\rock.00096.au
# data\genres\rock\rock.00097.au
# data\genres\rock\rock.00098.au
# data\genres\rock\rock.00099.au

# %% [markdown]
# # Looking at music

# %%
import scipy.io.wavfile

from matplotlib.ticker import EngFormatter

def plot_specgram(ax, fn):
    sample_rate, X = scipy.io.wavfile.read(fn)
    ax.specgram(X, Fs=sample_rate, xextent=(0, 30), cmap='hot')

GENRES = ["classical", "jazz", "country", "pop", "rock", "metal"]

def plot_specgrams():
    """
    Plot a bunch of spectrograms of wav files in different genres
    """
    plt.clf()
    
    num_files = 3
    f, axes = plt.subplots(len(GENRES), num_files, dpi=DPI, figsize=(6, 8))
    
    for genre_idx, genre in enumerate(GENRES):
        for idx, fn in enumerate((Path(GENRE_DIR) / genre).glob('*.wav')):
            if idx == num_files:
                break
            
            axis = axes[genre_idx, idx]
            axis.tick_params(direction='out', length=0, width=1, labelsize=5)
    
            axis.yaxis.set_major_formatter(EngFormatter())
            axis.set_title("%s song %i" % (genre, idx + 1), fontsize=7)
            plot_specgram(axis, fn)
        
    plt.subplots_adjust(hspace=0.5)
    save_png("5_Spectrogram_Genres")
    
plot_specgrams()

# %% [markdown]
# # Playing with waves

# %%
!"C:\Program Files (x86)\sox-14-4-2\sox.exe" --null -r 22050 sine_a.wav synth 0.2 sine 400

# %%
!"C:\Program Files (x86)\sox-14-4-2\sox.exe" --null -r 22050 sine_b.wav synth 0.2 sine 3000

# %%
!"C:\Program Files (x86)\sox-14-4-2\sox.exe" --combine mix --volume 1 sine_b.wav --volume 0.5 sine_a.wav sine_mix.wav
# Out:
# C:\Program Files (x86)\sox-14-4-2\sox.exe WARN sox: mix-combining clipped 140 samples; decrease volume?

# %% [markdown]
# Now we have three files `sine_a.wav`, `sine_b.wav`, `sine_mix.wav` in the current directory, which we can visualize.

# %%
import scipy

def plot_wav_fft(wav_filename, desc=None, plot=0):
    plt.clf()
    plt.figure(num=None, figsize=(6, 4), dpi=DPI)
    sample_rate, X = scipy.io.wavfile.read(wav_filename)
    spectrum = np.fft.fft(X)
    freq = np.fft.fftfreq(len(X), 1.0 / sample_rate)

    plt.subplot(211)
    num_samples = 200
    plt.xlim(0, num_samples / sample_rate)
    plt.xlabel("time [s]")
    plt.title(desc or wav_filename)
    plt.plot(np.arange(num_samples) / sample_rate, X[:num_samples])
    plt.grid(True)

    plt.subplot(212)
    plt.xlim(0, 5000)
    plt.xlabel("frequency [Hz]")
    plt.xticks(np.arange(5) * 1000)
    if desc:
        desc = desc.strip()
        fft_desc = desc[0].lower() + desc[1:]
    else:
        fft_desc = wav_filename
    plt.title("FFT of %s" % fft_desc)
    plt.plot(freq, abs(spectrum), linewidth=2)
    plt.grid(True)

    plt.tight_layout()

    rel_filename = os.path.split(wav_filename)[1]
    save_png("%i_%s_wav_fft" % (plot, os.path.splitext(rel_filename)[0]))

    plt.show()


plot_wav_fft("sine_a.wav", "400Hz sine wave", 1)
plot_wav_fft("sine_b.wav", "3,000Hz sine wave", 2)
plot_wav_fft("sine_mix.wav", "Mixed sine wave", 3)

# %% [markdown]
# A "real" music file looks a bit noisier:

# %%
plot_wav_fft(Path(GENRE_DIR) / 'disco' / 'disco.00000.wav', "some sample song", 4)

# %% [markdown]
# # First classifier using FFT

# %% [markdown]
# ## Generating FFT features

# %%
def create_fft(fn):
    sample_rate, X = scipy.io.wavfile.read(fn)

    fft_features = abs(scipy.fft(X)[:1000])
    np.save(Path(fn).with_suffix('.fft'), fft_features)
    
for wav_fn in Path(GENRE_DIR).glob('**/*.wav'):
    print('Converting %s ...' % str(wav_fn))
    create_fft(wav_fn)
# Out:
# Converting data\genres\blues\blues.00000.wav ...
# Converting data\genres\blues\blues.00001.wav ...
# Converting data\genres\blues\blues.00002.wav ...
# Converting data\genres\blues\blues.00003.wav ...
# Converting data\genres\blues\blues.00004.wav ...
# Converting data\genres\blues\blues.00005.wav ...
# Converting data\genres\blues\blues.00006.wav ...
# Converting data\genres\blues\blues.00007.wav ...
# Converting data\genres\blues\blues.00008.wav ...
# Converting data\genres\blues\blues.00009.wav ...
# Converting data\genres\blues\blues.00010.wav ...
# Converting data\genres\blues\blues.00011.wav ...
# Converting data\genres\blues\blues.00012.wav ...
# Converting data\genres\blues\blues.00013.wav ...
# Converting data\genres\blues\blues.00014.wav ...
# Converting data\genres\blues\blues.00015.wav ...
# Converting data\genres\blues\blues.00016.wav ...
# Converting data\genres\blues\blues.00017.wav ...
# Converting data\genres\blues\blues.00018.wav ...
# Converting data\genres\blues\blues.00019.wav ...
# Converting data\genres\blues\blues.00020.wav ...
# Converting data\genres\blues\blues.00021.wav ...
# Converting data\genres\blues\blues.00022.wav ...
# Converting data\genres\blues\blues.00023.wav ...
# Converting data\genres\blues\blues.00024.wav ...
# Converting data\genres\blues\blues.00025.wav ...
# Converting data\genres\blues\blues.00026.wav ...
# Converting data\genres\blues\blues.00027.wav ...
# Converting data\genres\blues\blues.00028.wav ...
# Converting data\genres\blues\blues.00029.wav ...
# Converting data\genres\blues\blues.00030.wav ...
# Converting data\genres\blues\blues.00031.wav ...
# Converting data\genres\blues\blues.00032.wav ...
# Converting data\genres\blues\blues.00033.wav ...
# Converting data\genres\blues\blues.00034.wav ...
# Converting data\genres\blues\blues.00035.wav ...
# Converting data\genres\blues\blues.00036.wav ...
# Converting data\genres\blues\blues.00037.wav ...
# Converting data\genres\blues\blues.00038.wav ...
# Converting data\genres\blues\blues.00039.wav ...
# Converting data\genres\blues\blues.00040.wav ...
# Converting data\genres\blues\blues.00041.wav ...
# Converting data\genres\blues\blues.00042.wav ...
# Converting data\genres\blues\blues.00043.wav ...
# Converting data\genres\blues\blues.00044.wav ...
# Converting data\genres\blues\blues.00045.wav ...
# Converting data\genres\blues\blues.00046.wav ...
# Converting data\genres\blues\blues.00047.wav ...
# Converting data\genres\blues\blues.00048.wav ...
# Converting data\genres\blues\blues.00049.wav ...
# Converting data\genres\blues\blues.00050.wav ...
# Converting data\genres\blues\blues.00051.wav ...
# Converting data\genres\blues\blues.00052.wav ...
# Converting data\genres\blues\blues.00053.wav ...
# Converting data\genres\blues\blues.00054.wav ...
# Converting data\genres\blues\blues.00055.wav ...
# Converting data\genres\blues\blues.00056.wav ...
# Converting data\genres\blues\blues.00057.wav ...
# Converting data\genres\blues\blues.00058.wav ...
# Converting data\genres\blues\blues.00059.wav ...
# Converting data\genres\blues\blues.00060.wav ...
# Converting data\genres\blues\blues.00061.wav ...
# Converting data\genres\blues\blues.00062.wav ...
# Converting data\genres\blues\blues.00063.wav ...
# Converting data\genres\blues\blues.00064.wav ...
# Converting data\genres\blues\blues.00065.wav ...
# Converting data\genres\blues\blues.00066.wav ...
# Converting data\genres\blues\blues.00067.wav ...
# Converting data\genres\blues\blues.00068.wav ...
# Converting data\genres\blues\blues.00069.wav ...
# Converting data\genres\blues\blues.00070.wav ...
# Converting data\genres\blues\blues.00071.wav ...
# Converting data\genres\blues\blues.00072.wav ...
# Converting data\genres\blues\blues.00073.wav ...
# Converting data\genres\blues\blues.00074.wav ...
# Converting data\genres\blues\blues.00075.wav ...
# Converting data\genres\blues\blues.00076.wav ...
# Converting data\genres\blues\blues.00077.wav ...
# Converting data\genres\blues\blues.00078.wav ...
# Converting data\genres\blues\blues.00079.wav ...
# Converting data\genres\blues\blues.00080.wav ...
# Converting data\genres\blues\blues.00081.wav ...
# Converting data\genres\blues\blues.00082.wav ...
# Converting data\genres\blues\blues.00083.wav ...
# Converting data\genres\blues\blues.00084.wav ...
# Converting data\genres\blues\blues.00085.wav ...
# Converting data\genres\blues\blues.00086.wav ...
# Converting data\genres\blues\blues.00087.wav ...
# Converting data\genres\blues\blues.00088.wav ...
# Converting data\genres\blues\blues.00089.wav ...
# Converting data\genres\blues\blues.00090.wav ...
# Converting data\genres\blues\blues.00091.wav ...
# Converting data\genres\blues\blues.00092.wav ...
# Converting data\genres\blues\blues.00093.wav ...
# Converting data\genres\blues\blues.00094.wav ...
# Converting data\genres\blues\blues.00095.wav ...
# Converting data\genres\blues\blues.00096.wav ...
# Converting data\genres\blues\blues.00097.wav ...
# Converting data\genres\blues\blues.00098.wav ...
# Converting data\genres\blues\blues.00099.wav ...
# Converting data\genres\classical\classical.00000.wav ...
# Converting data\genres\classical\classical.00001.wav ...
# Converting data\genres\classical\classical.00002.wav ...
# Converting data\genres\classical\classical.00003.wav ...
# Converting data\genres\classical\classical.00004.wav ...
# Converting data\genres\classical\classical.00005.wav ...
# Converting data\genres\classical\classical.00006.wav ...
# Converting data\genres\classical\classical.00007.wav ...
# Converting data\genres\classical\classical.00008.wav ...
# Converting data\genres\classical\classical.00009.wav ...
# Converting data\genres\classical\classical.00010.wav ...
# Converting data\genres\classical\classical.00011.wav ...
# Converting data\genres\classical\classical.00012.wav ...
# Converting data\genres\classical\classical.00013.wav ...
# Converting data\genres\classical\classical.00014.wav ...
# Converting data\genres\classical\classical.00015.wav ...
# Converting data\genres\classical\classical.00016.wav ...
# Converting data\genres\classical\classical.00017.wav ...
# Converting data\genres\classical\classical.00018.wav ...
# Converting data\genres\classical\classical.00019.wav ...
# Converting data\genres\classical\classical.00020.wav ...
# Converting data\genres\classical\classical.00021.wav ...
# Converting data\genres\classical\classical.00022.wav ...
# Converting data\genres\classical\classical.00023.wav ...
# Converting data\genres\classical\classical.00024.wav ...
# Converting data\genres\classical\classical.00025.wav ...
# Converting data\genres\classical\classical.00026.wav ...
# Converting data\genres\classical\classical.00027.wav ...
# Converting data\genres\classical\classical.00028.wav ...
# Converting data\genres\classical\classical.00029.wav ...
# Converting data\genres\classical\classical.00030.wav ...
# Converting data\genres\classical\classical.00031.wav ...
# Converting data\genres\classical\classical.00032.wav ...
# Converting data\genres\classical\classical.00033.wav ...
# Converting data\genres\classical\classical.00034.wav ...
# Converting data\genres\classical\classical.00035.wav ...
# Converting data\genres\classical\classical.00036.wav ...
# Converting data\genres\classical\classical.00037.wav ...
# Converting data\genres\classical\classical.00038.wav ...
# Converting data\genres\classical\classical.00039.wav ...
# Converting data\genres\classical\classical.00040.wav ...
# Converting data\genres\classical\classical.00041.wav ...
# Converting data\genres\classical\classical.00042.wav ...
# Converting data\genres\classical\classical.00043.wav ...
# Converting data\genres\classical\classical.00044.wav ...
# Converting data\genres\classical\classical.00045.wav ...
# Converting data\genres\classical\classical.00046.wav ...
# Converting data\genres\classical\classical.00047.wav ...
# Converting data\genres\classical\classical.00048.wav ...
# Converting data\genres\classical\classical.00049.wav ...
# Converting data\genres\classical\classical.00050.wav ...
# Converting data\genres\classical\classical.00051.wav ...
# Converting data\genres\classical\classical.00052.wav ...
# Converting data\genres\classical\classical.00053.wav ...
# Converting data\genres\classical\classical.00054.wav ...
# Converting data\genres\classical\classical.00055.wav ...
# Converting data\genres\classical\classical.00056.wav ...
# Converting data\genres\classical\classical.00057.wav ...
# Converting data\genres\classical\classical.00058.wav ...
# Converting data\genres\classical\classical.00059.wav ...
# Converting data\genres\classical\classical.00060.wav ...
# Converting data\genres\classical\classical.00061.wav ...
# Converting data\genres\classical\classical.00062.wav ...
# Converting data\genres\classical\classical.00063.wav ...
# Converting data\genres\classical\classical.00064.wav ...
# Converting data\genres\classical\classical.00065.wav ...
# Converting data\genres\classical\classical.00066.wav ...
# Converting data\genres\classical\classical.00067.wav ...
# Converting data\genres\classical\classical.00068.wav ...
# Converting data\genres\classical\classical.00069.wav ...
# Converting data\genres\classical\classical.00070.wav ...
# Converting data\genres\classical\classical.00071.wav ...
# Converting data\genres\classical\classical.00072.wav ...
# Converting data\genres\classical\classical.00073.wav ...
# Converting data\genres\classical\classical.00074.wav ...
# Converting data\genres\classical\classical.00075.wav ...
# Converting data\genres\classical\classical.00076.wav ...
# Converting data\genres\classical\classical.00077.wav ...
# Converting data\genres\classical\classical.00078.wav ...
# Converting data\genres\classical\classical.00079.wav ...
# Converting data\genres\classical\classical.00080.wav ...
# Converting data\genres\classical\classical.00081.wav ...
# Converting data\genres\classical\classical.00082.wav ...
# Converting data\genres\classical\classical.00083.wav ...
# Converting data\genres\classical\classical.00084.wav ...
# Converting data\genres\classical\classical.00085.wav ...
# Converting data\genres\classical\classical.00086.wav ...
# Converting data\genres\classical\classical.00087.wav ...
# Converting data\genres\classical\classical.00088.wav ...
# Converting data\genres\classical\classical.00089.wav ...
# Converting data\genres\classical\classical.00090.wav ...
# Converting data\genres\classical\classical.00091.wav ...
# Converting data\genres\classical\classical.00092.wav ...
# Converting data\genres\classical\classical.00093.wav ...
# Converting data\genres\classical\classical.00094.wav ...
# Converting data\genres\classical\classical.00095.wav ...
# Converting data\genres\classical\classical.00096.wav ...
# Converting data\genres\classical\classical.00097.wav ...
# Converting data\genres\classical\classical.00098.wav ...
# Converting data\genres\classical\classical.00099.wav ...
# Converting data\genres\country\country.00000.wav ...
# Converting data\genres\country\country.00001.wav ...
# Converting data\genres\country\country.00002.wav ...
# Converting data\genres\country\country.00003.wav ...
# Converting data\genres\country\country.00004.wav ...
# Converting data\genres\country\country.00005.wav ...
# Converting data\genres\country\country.00006.wav ...
# Converting data\genres\country\country.00007.wav ...
# Converting data\genres\country\country.00008.wav ...
# Converting data\genres\country\country.00009.wav ...
# Converting data\genres\country\country.00010.wav ...
# Converting data\genres\country\country.00011.wav ...
# Converting data\genres\country\country.00012.wav ...
# Converting data\genres\country\country.00013.wav ...
# Converting data\genres\country\country.00014.wav ...
# Converting data\genres\country\country.00015.wav ...
# Converting data\genres\country\country.00016.wav ...
# Converting data\genres\country\country.00017.wav ...
# Converting data\genres\country\country.00018.wav ...
# Converting data\genres\country\country.00019.wav ...
# Converting data\genres\country\country.00020.wav ...
# Converting data\genres\country\country.00021.wav ...
# Converting data\genres\country\country.00022.wav ...
# Converting data\genres\country\country.00023.wav ...
# Converting data\genres\country\country.00024.wav ...
# Converting data\genres\country\country.00025.wav ...
# Converting data\genres\country\country.00026.wav ...
# Converting data\genres\country\country.00027.wav ...
# Converting data\genres\country\country.00028.wav ...
# Converting data\genres\country\country.00029.wav ...
# Converting data\genres\country\country.00030.wav ...
# Converting data\genres\country\country.00031.wav ...
# Converting data\genres\country\country.00032.wav ...
# Converting data\genres\country\country.00033.wav ...
# Converting data\genres\country\country.00034.wav ...
# Converting data\genres\country\country.00035.wav ...
# Converting data\genres\country\country.00036.wav ...
# Converting data\genres\country\country.00037.wav ...
# Converting data\genres\country\country.00038.wav ...
# Converting data\genres\country\country.00039.wav ...
# Converting data\genres\country\country.00040.wav ...
# Converting data\genres\country\country.00041.wav ...
# Converting data\genres\country\country.00042.wav ...
# Converting data\genres\country\country.00043.wav ...
# Converting data\genres\country\country.00044.wav ...
# Converting data\genres\country\country.00045.wav ...
# Converting data\genres\country\country.00046.wav ...
# Converting data\genres\country\country.00047.wav ...
# Converting data\genres\country\country.00048.wav ...
# Converting data\genres\country\country.00049.wav ...
# Converting data\genres\country\country.00050.wav ...
# Converting data\genres\country\country.00051.wav ...
# Converting data\genres\country\country.00052.wav ...
# Converting data\genres\country\country.00053.wav ...
# Converting data\genres\country\country.00054.wav ...
# Converting data\genres\country\country.00055.wav ...
# Converting data\genres\country\country.00056.wav ...
# Converting data\genres\country\country.00057.wav ...
# Converting data\genres\country\country.00058.wav ...
# Converting data\genres\country\country.00059.wav ...
# Converting data\genres\country\country.00060.wav ...
# Converting data\genres\country\country.00061.wav ...
# Converting data\genres\country\country.00062.wav ...
# Converting data\genres\country\country.00063.wav ...
# Converting data\genres\country\country.00064.wav ...
# Converting data\genres\country\country.00065.wav ...
# Converting data\genres\country\country.00066.wav ...
# Converting data\genres\country\country.00067.wav ...
# Converting data\genres\country\country.00068.wav ...
# Converting data\genres\country\country.00069.wav ...
# Converting data\genres\country\country.00070.wav ...
# Converting data\genres\country\country.00071.wav ...
# Converting data\genres\country\country.00072.wav ...
# Converting data\genres\country\country.00073.wav ...
# Converting data\genres\country\country.00074.wav ...
# Converting data\genres\country\country.00075.wav ...
# Converting data\genres\country\country.00076.wav ...
# Converting data\genres\country\country.00077.wav ...
# Converting data\genres\country\country.00078.wav ...
# Converting data\genres\country\country.00079.wav ...
# Converting data\genres\country\country.00080.wav ...
# Converting data\genres\country\country.00081.wav ...
# Converting data\genres\country\country.00082.wav ...
# Converting data\genres\country\country.00083.wav ...
# Converting data\genres\country\country.00084.wav ...
# Converting data\genres\country\country.00085.wav ...
# Converting data\genres\country\country.00086.wav ...
# Converting data\genres\country\country.00087.wav ...
# Converting data\genres\country\country.00088.wav ...
# Converting data\genres\country\country.00089.wav ...
# Converting data\genres\country\country.00090.wav ...
# Converting data\genres\country\country.00091.wav ...
# Converting data\genres\country\country.00092.wav ...
# Converting data\genres\country\country.00093.wav ...
# Converting data\genres\country\country.00094.wav ...
# Converting data\genres\country\country.00095.wav ...
# Converting data\genres\country\country.00096.wav ...
# Converting data\genres\country\country.00097.wav ...
# Converting data\genres\country\country.00098.wav ...
# Converting data\genres\country\country.00099.wav ...
# Converting data\genres\disco\disco.00000.wav ...
# Converting data\genres\disco\disco.00001.wav ...
# Converting data\genres\disco\disco.00002.wav ...
# Converting data\genres\disco\disco.00003.wav ...
# Converting data\genres\disco\disco.00004.wav ...
# Converting data\genres\disco\disco.00005.wav ...
# Converting data\genres\disco\disco.00006.wav ...
# Converting data\genres\disco\disco.00007.wav ...
# Converting data\genres\disco\disco.00008.wav ...
# Converting data\genres\disco\disco.00009.wav ...
# Converting data\genres\disco\disco.00010.wav ...
# Converting data\genres\disco\disco.00011.wav ...
# Converting data\genres\disco\disco.00012.wav ...
# Converting data\genres\disco\disco.00013.wav ...
# Converting data\genres\disco\disco.00014.wav ...
# Converting data\genres\disco\disco.00015.wav ...
# Converting data\genres\disco\disco.00016.wav ...
# Converting data\genres\disco\disco.00017.wav ...
# Converting data\genres\disco\disco.00018.wav ...
# Converting data\genres\disco\disco.00019.wav ...
# Converting data\genres\disco\disco.00020.wav ...
# Converting data\genres\disco\disco.00021.wav ...
# Converting data\genres\disco\disco.00022.wav ...
# Converting data\genres\disco\disco.00023.wav ...
# Converting data\genres\disco\disco.00024.wav ...
# Converting data\genres\disco\disco.00025.wav ...
# Converting data\genres\disco\disco.00026.wav ...
# Converting data\genres\disco\disco.00027.wav ...
# Converting data\genres\disco\disco.00028.wav ...
# Converting data\genres\disco\disco.00029.wav ...
# Converting data\genres\disco\disco.00030.wav ...
# Converting data\genres\disco\disco.00031.wav ...
# Converting data\genres\disco\disco.00032.wav ...
# Converting data\genres\disco\disco.00033.wav ...
# Converting data\genres\disco\disco.00034.wav ...
# Converting data\genres\disco\disco.00035.wav ...
# Converting data\genres\disco\disco.00036.wav ...
# Converting data\genres\disco\disco.00037.wav ...
# Converting data\genres\disco\disco.00038.wav ...
# Converting data\genres\disco\disco.00039.wav ...
# Converting data\genres\disco\disco.00040.wav ...
# Converting data\genres\disco\disco.00041.wav ...
# Converting data\genres\disco\disco.00042.wav ...
# Converting data\genres\disco\disco.00043.wav ...
# Converting data\genres\disco\disco.00044.wav ...
# Converting data\genres\disco\disco.00045.wav ...
# Converting data\genres\disco\disco.00046.wav ...
# Converting data\genres\disco\disco.00047.wav ...
# Converting data\genres\disco\disco.00048.wav ...
# Converting data\genres\disco\disco.00049.wav ...
# Converting data\genres\disco\disco.00050.wav ...
# Converting data\genres\disco\disco.00051.wav ...
# Converting data\genres\disco\disco.00052.wav ...
# Converting data\genres\disco\disco.00053.wav ...
# Converting data\genres\disco\disco.00054.wav ...
# Converting data\genres\disco\disco.00055.wav ...
# Converting data\genres\disco\disco.00056.wav ...
# Converting data\genres\disco\disco.00057.wav ...
# Converting data\genres\disco\disco.00058.wav ...
# Converting data\genres\disco\disco.00059.wav ...
# Converting data\genres\disco\disco.00060.wav ...
# Converting data\genres\disco\disco.00061.wav ...
# Converting data\genres\disco\disco.00062.wav ...
# Converting data\genres\disco\disco.00063.wav ...
# Converting data\genres\disco\disco.00064.wav ...
# Converting data\genres\disco\disco.00065.wav ...
# Converting data\genres\disco\disco.00066.wav ...
# Converting data\genres\disco\disco.00067.wav ...
# Converting data\genres\disco\disco.00068.wav ...
# Converting data\genres\disco\disco.00069.wav ...
# Converting data\genres\disco\disco.00070.wav ...
# Converting data\genres\disco\disco.00071.wav ...
# Converting data\genres\disco\disco.00072.wav ...
# Converting data\genres\disco\disco.00073.wav ...
# Converting data\genres\disco\disco.00074.wav ...
# Converting data\genres\disco\disco.00075.wav ...
# Converting data\genres\disco\disco.00076.wav ...
# Converting data\genres\disco\disco.00077.wav ...
# Converting data\genres\disco\disco.00078.wav ...
# Converting data\genres\disco\disco.00079.wav ...
# Converting data\genres\disco\disco.00080.wav ...
# Converting data\genres\disco\disco.00081.wav ...
# Converting data\genres\disco\disco.00082.wav ...
# Converting data\genres\disco\disco.00083.wav ...
# Converting data\genres\disco\disco.00084.wav ...
# Converting data\genres\disco\disco.00085.wav ...
# Converting data\genres\disco\disco.00086.wav ...
# Converting data\genres\disco\disco.00087.wav ...
# Converting data\genres\disco\disco.00088.wav ...
# Converting data\genres\disco\disco.00089.wav ...
# Converting data\genres\disco\disco.00090.wav ...
# Converting data\genres\disco\disco.00091.wav ...
# Converting data\genres\disco\disco.00092.wav ...
# Converting data\genres\disco\disco.00093.wav ...
# Converting data\genres\disco\disco.00094.wav ...
# Converting data\genres\disco\disco.00095.wav ...
# Converting data\genres\disco\disco.00096.wav ...
# Converting data\genres\disco\disco.00097.wav ...
# Converting data\genres\disco\disco.00098.wav ...
# Converting data\genres\disco\disco.00099.wav ...
# Converting data\genres\hiphop\hiphop.00000.wav ...
# Converting data\genres\hiphop\hiphop.00001.wav ...
# Converting data\genres\hiphop\hiphop.00002.wav ...
# Converting data\genres\hiphop\hiphop.00003.wav ...
# Converting data\genres\hiphop\hiphop.00004.wav ...
# Converting data\genres\hiphop\hiphop.00005.wav ...
# Converting data\genres\hiphop\hiphop.00006.wav ...
# Converting data\genres\hiphop\hiphop.00007.wav ...
# Converting data\genres\hiphop\hiphop.00008.wav ...
# Converting data\genres\hiphop\hiphop.00009.wav ...
# Converting data\genres\hiphop\hiphop.00010.wav ...
# Converting data\genres\hiphop\hiphop.00011.wav ...
# Converting data\genres\hiphop\hiphop.00012.wav ...
# Converting data\genres\hiphop\hiphop.00013.wav ...
# Converting data\genres\hiphop\hiphop.00014.wav ...
# Converting data\genres\hiphop\hiphop.00015.wav ...
# Converting data\genres\hiphop\hiphop.00016.wav ...
# Converting data\genres\hiphop\hiphop.00017.wav ...
# Converting data\genres\hiphop\hiphop.00018.wav ...
# Converting data\genres\hiphop\hiphop.00019.wav ...
# Converting data\genres\hiphop\hiphop.00020.wav ...
# Converting data\genres\hiphop\hiphop.00021.wav ...
# Converting data\genres\hiphop\hiphop.00022.wav ...
# Converting data\genres\hiphop\hiphop.00023.wav ...
# Converting data\genres\hiphop\hiphop.00024.wav ...
# Converting data\genres\hiphop\hiphop.00025.wav ...
# Converting data\genres\hiphop\hiphop.00026.wav ...
# Converting data\genres\hiphop\hiphop.00027.wav ...
# Converting data\genres\hiphop\hiphop.00028.wav ...
# Converting data\genres\hiphop\hiphop.00029.wav ...
# Converting data\genres\hiphop\hiphop.00030.wav ...
# Converting data\genres\hiphop\hiphop.00031.wav ...
# Converting data\genres\hiphop\hiphop.00032.wav ...
# Converting data\genres\hiphop\hiphop.00033.wav ...
# Converting data\genres\hiphop\hiphop.00034.wav ...
# Converting data\genres\hiphop\hiphop.00035.wav ...
# Converting data\genres\hiphop\hiphop.00036.wav ...
# Converting data\genres\hiphop\hiphop.00037.wav ...
# Converting data\genres\hiphop\hiphop.00038.wav ...
# Converting data\genres\hiphop\hiphop.00039.wav ...
# Converting data\genres\hiphop\hiphop.00040.wav ...
# Converting data\genres\hiphop\hiphop.00041.wav ...
# Converting data\genres\hiphop\hiphop.00042.wav ...
# Converting data\genres\hiphop\hiphop.00043.wav ...
# Converting data\genres\hiphop\hiphop.00044.wav ...
# Converting data\genres\hiphop\hiphop.00045.wav ...
# Converting data\genres\hiphop\hiphop.00046.wav ...
# Converting data\genres\hiphop\hiphop.00047.wav ...
# Converting data\genres\hiphop\hiphop.00048.wav ...
# Converting data\genres\hiphop\hiphop.00049.wav ...
# Converting data\genres\hiphop\hiphop.00050.wav ...
# Converting data\genres\hiphop\hiphop.00051.wav ...
# Converting data\genres\hiphop\hiphop.00052.wav ...
# Converting data\genres\hiphop\hiphop.00053.wav ...
# Converting data\genres\hiphop\hiphop.00054.wav ...
# Converting data\genres\hiphop\hiphop.00055.wav ...
# Converting data\genres\hiphop\hiphop.00056.wav ...
# Converting data\genres\hiphop\hiphop.00057.wav ...
# Converting data\genres\hiphop\hiphop.00058.wav ...
# Converting data\genres\hiphop\hiphop.00059.wav ...
# Converting data\genres\hiphop\hiphop.00060.wav ...
# Converting data\genres\hiphop\hiphop.00061.wav ...
# Converting data\genres\hiphop\hiphop.00062.wav ...
# Converting data\genres\hiphop\hiphop.00063.wav ...
# Converting data\genres\hiphop\hiphop.00064.wav ...
# Converting data\genres\hiphop\hiphop.00065.wav ...
# Converting data\genres\hiphop\hiphop.00066.wav ...
# Converting data\genres\hiphop\hiphop.00067.wav ...
# Converting data\genres\hiphop\hiphop.00068.wav ...
# Converting data\genres\hiphop\hiphop.00069.wav ...
# Converting data\genres\hiphop\hiphop.00070.wav ...
# Converting data\genres\hiphop\hiphop.00071.wav ...
# Converting data\genres\hiphop\hiphop.00072.wav ...
# Converting data\genres\hiphop\hiphop.00073.wav ...
# Converting data\genres\hiphop\hiphop.00074.wav ...
# Converting data\genres\hiphop\hiphop.00075.wav ...
# Converting data\genres\hiphop\hiphop.00076.wav ...
# Converting data\genres\hiphop\hiphop.00077.wav ...
# Converting data\genres\hiphop\hiphop.00078.wav ...
# Converting data\genres\hiphop\hiphop.00079.wav ...
# Converting data\genres\hiphop\hiphop.00080.wav ...
# Converting data\genres\hiphop\hiphop.00081.wav ...
# Converting data\genres\hiphop\hiphop.00082.wav ...
# Converting data\genres\hiphop\hiphop.00083.wav ...
# Converting data\genres\hiphop\hiphop.00084.wav ...
# Converting data\genres\hiphop\hiphop.00085.wav ...
# Converting data\genres\hiphop\hiphop.00086.wav ...
# Converting data\genres\hiphop\hiphop.00087.wav ...
# Converting data\genres\hiphop\hiphop.00088.wav ...
# Converting data\genres\hiphop\hiphop.00089.wav ...
# Converting data\genres\hiphop\hiphop.00090.wav ...
# Converting data\genres\hiphop\hiphop.00091.wav ...
# Converting data\genres\hiphop\hiphop.00092.wav ...
# Converting data\genres\hiphop\hiphop.00093.wav ...
# Converting data\genres\hiphop\hiphop.00094.wav ...
# Converting data\genres\hiphop\hiphop.00095.wav ...
# Converting data\genres\hiphop\hiphop.00096.wav ...
# Converting data\genres\hiphop\hiphop.00097.wav ...
# Converting data\genres\hiphop\hiphop.00098.wav ...
# Converting data\genres\hiphop\hiphop.00099.wav ...
# Converting data\genres\jazz\jazz.00000.wav ...
# Converting data\genres\jazz\jazz.00001.wav ...
# Converting data\genres\jazz\jazz.00002.wav ...
# Converting data\genres\jazz\jazz.00003.wav ...
# Converting data\genres\jazz\jazz.00004.wav ...
# Converting data\genres\jazz\jazz.00005.wav ...
# Converting data\genres\jazz\jazz.00006.wav ...
# Converting data\genres\jazz\jazz.00007.wav ...
# Converting data\genres\jazz\jazz.00008.wav ...
# Converting data\genres\jazz\jazz.00009.wav ...
# Converting data\genres\jazz\jazz.00010.wav ...
# Converting data\genres\jazz\jazz.00011.wav ...
# Converting data\genres\jazz\jazz.00012.wav ...
# Converting data\genres\jazz\jazz.00013.wav ...
# Converting data\genres\jazz\jazz.00014.wav ...
# Converting data\genres\jazz\jazz.00015.wav ...
# Converting data\genres\jazz\jazz.00016.wav ...
# Converting data\genres\jazz\jazz.00017.wav ...
# Converting data\genres\jazz\jazz.00018.wav ...
# Converting data\genres\jazz\jazz.00019.wav ...
# Converting data\genres\jazz\jazz.00020.wav ...
# Converting data\genres\jazz\jazz.00021.wav ...
# Converting data\genres\jazz\jazz.00022.wav ...
# Converting data\genres\jazz\jazz.00023.wav ...
# Converting data\genres\jazz\jazz.00024.wav ...
# Converting data\genres\jazz\jazz.00025.wav ...
# Converting data\genres\jazz\jazz.00026.wav ...
# Converting data\genres\jazz\jazz.00027.wav ...
# Converting data\genres\jazz\jazz.00028.wav ...
# Converting data\genres\jazz\jazz.00029.wav ...
# Converting data\genres\jazz\jazz.00030.wav ...
# Converting data\genres\jazz\jazz.00031.wav ...
# Converting data\genres\jazz\jazz.00032.wav ...
# Converting data\genres\jazz\jazz.00033.wav ...
# Converting data\genres\jazz\jazz.00034.wav ...
# Converting data\genres\jazz\jazz.00035.wav ...
# Converting data\genres\jazz\jazz.00036.wav ...
# Converting data\genres\jazz\jazz.00037.wav ...
# Converting data\genres\jazz\jazz.00038.wav ...
# Converting data\genres\jazz\jazz.00039.wav ...
# Converting data\genres\jazz\jazz.00040.wav ...
# Converting data\genres\jazz\jazz.00041.wav ...
# Converting data\genres\jazz\jazz.00042.wav ...
# Converting data\genres\jazz\jazz.00043.wav ...
# Converting data\genres\jazz\jazz.00044.wav ...
# Converting data\genres\jazz\jazz.00045.wav ...
# Converting data\genres\jazz\jazz.00046.wav ...
# Converting data\genres\jazz\jazz.00047.wav ...
# Converting data\genres\jazz\jazz.00048.wav ...
# Converting data\genres\jazz\jazz.00049.wav ...
# Converting data\genres\jazz\jazz.00050.wav ...
# Converting data\genres\jazz\jazz.00051.wav ...
# Converting data\genres\jazz\jazz.00052.wav ...
# Converting data\genres\jazz\jazz.00053.wav ...
# Converting data\genres\jazz\jazz.00054.wav ...
# Converting data\genres\jazz\jazz.00055.wav ...
# Converting data\genres\jazz\jazz.00056.wav ...
# Converting data\genres\jazz\jazz.00057.wav ...
# Converting data\genres\jazz\jazz.00058.wav ...
# Converting data\genres\jazz\jazz.00059.wav ...
# Converting data\genres\jazz\jazz.00060.wav ...
# Converting data\genres\jazz\jazz.00061.wav ...
# Converting data\genres\jazz\jazz.00062.wav ...
# Converting data\genres\jazz\jazz.00063.wav ...
# Converting data\genres\jazz\jazz.00064.wav ...
# Converting data\genres\jazz\jazz.00065.wav ...
# Converting data\genres\jazz\jazz.00066.wav ...
# Converting data\genres\jazz\jazz.00067.wav ...
# Converting data\genres\jazz\jazz.00068.wav ...
# Converting data\genres\jazz\jazz.00069.wav ...
# Converting data\genres\jazz\jazz.00070.wav ...
# Converting data\genres\jazz\jazz.00071.wav ...
# Converting data\genres\jazz\jazz.00072.wav ...
# Converting data\genres\jazz\jazz.00073.wav ...
# Converting data\genres\jazz\jazz.00074.wav ...
# Converting data\genres\jazz\jazz.00075.wav ...
# Converting data\genres\jazz\jazz.00076.wav ...
# Converting data\genres\jazz\jazz.00077.wav ...
# Converting data\genres\jazz\jazz.00078.wav ...
# Converting data\genres\jazz\jazz.00079.wav ...
# Converting data\genres\jazz\jazz.00080.wav ...
# Converting data\genres\jazz\jazz.00081.wav ...
# Converting data\genres\jazz\jazz.00082.wav ...
# Converting data\genres\jazz\jazz.00083.wav ...
# Converting data\genres\jazz\jazz.00084.wav ...
# Converting data\genres\jazz\jazz.00085.wav ...
# Converting data\genres\jazz\jazz.00086.wav ...
# Converting data\genres\jazz\jazz.00087.wav ...
# Converting data\genres\jazz\jazz.00088.wav ...
# Converting data\genres\jazz\jazz.00089.wav ...
# Converting data\genres\jazz\jazz.00090.wav ...
# Converting data\genres\jazz\jazz.00091.wav ...
# Converting data\genres\jazz\jazz.00092.wav ...
# Converting data\genres\jazz\jazz.00093.wav ...
# Converting data\genres\jazz\jazz.00094.wav ...
# Converting data\genres\jazz\jazz.00095.wav ...
# Converting data\genres\jazz\jazz.00096.wav ...
# Converting data\genres\jazz\jazz.00097.wav ...
# Converting data\genres\jazz\jazz.00098.wav ...
# Converting data\genres\jazz\jazz.00099.wav ...
# Converting data\genres\metal\metal.00000.wav ...
# Converting data\genres\metal\metal.00001.wav ...
# Converting data\genres\metal\metal.00002.wav ...
# Converting data\genres\metal\metal.00003.wav ...
# Converting data\genres\metal\metal.00004.wav ...
# Converting data\genres\metal\metal.00005.wav ...
# Converting data\genres\metal\metal.00006.wav ...
# Converting data\genres\metal\metal.00007.wav ...
# Converting data\genres\metal\metal.00008.wav ...
# Converting data\genres\metal\metal.00009.wav ...
# Converting data\genres\metal\metal.00010.wav ...
# Converting data\genres\metal\metal.00011.wav ...
# Converting data\genres\metal\metal.00012.wav ...
# Converting data\genres\metal\metal.00013.wav ...
# Converting data\genres\metal\metal.00014.wav ...
# Converting data\genres\metal\metal.00015.wav ...
# Converting data\genres\metal\metal.00016.wav ...
# Converting data\genres\metal\metal.00017.wav ...
# Converting data\genres\metal\metal.00018.wav ...
# Converting data\genres\metal\metal.00019.wav ...
# Converting data\genres\metal\metal.00020.wav ...
# Converting data\genres\metal\metal.00021.wav ...
# Converting data\genres\metal\metal.00022.wav ...
# Converting data\genres\metal\metal.00023.wav ...
# Converting data\genres\metal\metal.00024.wav ...
# Converting data\genres\metal\metal.00025.wav ...
# Converting data\genres\metal\metal.00026.wav ...
# Converting data\genres\metal\metal.00027.wav ...
# Converting data\genres\metal\metal.00028.wav ...
# Converting data\genres\metal\metal.00029.wav ...
# Converting data\genres\metal\metal.00030.wav ...
# Converting data\genres\metal\metal.00031.wav ...
# Converting data\genres\metal\metal.00032.wav ...
# Converting data\genres\metal\metal.00033.wav ...
# Converting data\genres\metal\metal.00034.wav ...
# Converting data\genres\metal\metal.00035.wav ...
# Converting data\genres\metal\metal.00036.wav ...
# Converting data\genres\metal\metal.00037.wav ...
# Converting data\genres\metal\metal.00038.wav ...
# Converting data\genres\metal\metal.00039.wav ...
# Converting data\genres\metal\metal.00040.wav ...
# Converting data\genres\metal\metal.00041.wav ...
# Converting data\genres\metal\metal.00042.wav ...
# Converting data\genres\metal\metal.00043.wav ...
# Converting data\genres\metal\metal.00044.wav ...
# Converting data\genres\metal\metal.00045.wav ...
# Converting data\genres\metal\metal.00046.wav ...
# Converting data\genres\metal\metal.00047.wav ...
# Converting data\genres\metal\metal.00048.wav ...
# Converting data\genres\metal\metal.00049.wav ...
# Converting data\genres\metal\metal.00050.wav ...
# Converting data\genres\metal\metal.00051.wav ...
# Converting data\genres\metal\metal.00052.wav ...
# Converting data\genres\metal\metal.00053.wav ...
# Converting data\genres\metal\metal.00054.wav ...
# Converting data\genres\metal\metal.00055.wav ...
# Converting data\genres\metal\metal.00056.wav ...
# Converting data\genres\metal\metal.00057.wav ...
# Converting data\genres\metal\metal.00058.wav ...
# Converting data\genres\metal\metal.00059.wav ...
# Converting data\genres\metal\metal.00060.wav ...
# Converting data\genres\metal\metal.00061.wav ...
# Converting data\genres\metal\metal.00062.wav ...
# Converting data\genres\metal\metal.00063.wav ...
# Converting data\genres\metal\metal.00064.wav ...
# Converting data\genres\metal\metal.00065.wav ...
# Converting data\genres\metal\metal.00066.wav ...
# Converting data\genres\metal\metal.00067.wav ...
# Converting data\genres\metal\metal.00068.wav ...
# Converting data\genres\metal\metal.00069.wav ...
# Converting data\genres\metal\metal.00070.wav ...
# Converting data\genres\metal\metal.00071.wav ...
# Converting data\genres\metal\metal.00072.wav ...
# Converting data\genres\metal\metal.00073.wav ...
# Converting data\genres\metal\metal.00074.wav ...
# Converting data\genres\metal\metal.00075.wav ...
# Converting data\genres\metal\metal.00076.wav ...
# Converting data\genres\metal\metal.00077.wav ...
# Converting data\genres\metal\metal.00078.wav ...
# Converting data\genres\metal\metal.00079.wav ...
# Converting data\genres\metal\metal.00080.wav ...
# Converting data\genres\metal\metal.00081.wav ...
# Converting data\genres\metal\metal.00082.wav ...
# Converting data\genres\metal\metal.00083.wav ...
# Converting data\genres\metal\metal.00084.wav ...
# Converting data\genres\metal\metal.00085.wav ...
# Converting data\genres\metal\metal.00086.wav ...
# Converting data\genres\metal\metal.00087.wav ...
# Converting data\genres\metal\metal.00088.wav ...
# Converting data\genres\metal\metal.00089.wav ...
# Converting data\genres\metal\metal.00090.wav ...
# Converting data\genres\metal\metal.00091.wav ...
# Converting data\genres\metal\metal.00092.wav ...
# Converting data\genres\metal\metal.00093.wav ...
# Converting data\genres\metal\metal.00094.wav ...
# Converting data\genres\metal\metal.00095.wav ...
# Converting data\genres\metal\metal.00096.wav ...
# Converting data\genres\metal\metal.00097.wav ...
# Converting data\genres\metal\metal.00098.wav ...
# Converting data\genres\metal\metal.00099.wav ...
# Converting data\genres\pop\pop.00000.wav ...
# Converting data\genres\pop\pop.00001.wav ...
# Converting data\genres\pop\pop.00002.wav ...
# Converting data\genres\pop\pop.00003.wav ...
# Converting data\genres\pop\pop.00004.wav ...
# Converting data\genres\pop\pop.00005.wav ...
# Converting data\genres\pop\pop.00006.wav ...
# Converting data\genres\pop\pop.00007.wav ...
# Converting data\genres\pop\pop.00008.wav ...
# Converting data\genres\pop\pop.00009.wav ...
# Converting data\genres\pop\pop.00010.wav ...
# Converting data\genres\pop\pop.00011.wav ...
# Converting data\genres\pop\pop.00012.wav ...
# Converting data\genres\pop\pop.00013.wav ...
# Converting data\genres\pop\pop.00014.wav ...
# Converting data\genres\pop\pop.00015.wav ...
# Converting data\genres\pop\pop.00016.wav ...
# Converting data\genres\pop\pop.00017.wav ...
# Converting data\genres\pop\pop.00018.wav ...
# Converting data\genres\pop\pop.00019.wav ...
# Converting data\genres\pop\pop.00020.wav ...
# Converting data\genres\pop\pop.00021.wav ...
# Converting data\genres\pop\pop.00022.wav ...
# Converting data\genres\pop\pop.00023.wav ...
# Converting data\genres\pop\pop.00024.wav ...
# Converting data\genres\pop\pop.00025.wav ...
# Converting data\genres\pop\pop.00026.wav ...
# Converting data\genres\pop\pop.00027.wav ...
# Converting data\genres\pop\pop.00028.wav ...
# Converting data\genres\pop\pop.00029.wav ...
# Converting data\genres\pop\pop.00030.wav ...
# Converting data\genres\pop\pop.00031.wav ...
# Converting data\genres\pop\pop.00032.wav ...
# Converting data\genres\pop\pop.00033.wav ...
# Converting data\genres\pop\pop.00034.wav ...
# Converting data\genres\pop\pop.00035.wav ...
# Converting data\genres\pop\pop.00036.wav ...
# Converting data\genres\pop\pop.00037.wav ...
# Converting data\genres\pop\pop.00038.wav ...
# Converting data\genres\pop\pop.00039.wav ...
# Converting data\genres\pop\pop.00040.wav ...
# Converting data\genres\pop\pop.00041.wav ...
# Converting data\genres\pop\pop.00042.wav ...
# Converting data\genres\pop\pop.00043.wav ...
# Converting data\genres\pop\pop.00044.wav ...
# Converting data\genres\pop\pop.00045.wav ...
# Converting data\genres\pop\pop.00046.wav ...
# Converting data\genres\pop\pop.00047.wav ...
# Converting data\genres\pop\pop.00048.wav ...
# Converting data\genres\pop\pop.00049.wav ...
# Converting data\genres\pop\pop.00050.wav ...
# Converting data\genres\pop\pop.00051.wav ...
# Converting data\genres\pop\pop.00052.wav ...
# Converting data\genres\pop\pop.00053.wav ...
# Converting data\genres\pop\pop.00054.wav ...
# Converting data\genres\pop\pop.00055.wav ...
# Converting data\genres\pop\pop.00056.wav ...
# Converting data\genres\pop\pop.00057.wav ...
# Converting data\genres\pop\pop.00058.wav ...
# Converting data\genres\pop\pop.00059.wav ...
# Converting data\genres\pop\pop.00060.wav ...
# Converting data\genres\pop\pop.00061.wav ...
# Converting data\genres\pop\pop.00062.wav ...
# Converting data\genres\pop\pop.00063.wav ...
# Converting data\genres\pop\pop.00064.wav ...
# Converting data\genres\pop\pop.00065.wav ...
# Converting data\genres\pop\pop.00066.wav ...
# Converting data\genres\pop\pop.00067.wav ...
# Converting data\genres\pop\pop.00068.wav ...
# Converting data\genres\pop\pop.00069.wav ...
# Converting data\genres\pop\pop.00070.wav ...
# Converting data\genres\pop\pop.00071.wav ...
# Converting data\genres\pop\pop.00072.wav ...
# Converting data\genres\pop\pop.00073.wav ...
# Converting data\genres\pop\pop.00074.wav ...
# Converting data\genres\pop\pop.00075.wav ...
# Converting data\genres\pop\pop.00076.wav ...
# Converting data\genres\pop\pop.00077.wav ...
# Converting data\genres\pop\pop.00078.wav ...
# Converting data\genres\pop\pop.00079.wav ...
# Converting data\genres\pop\pop.00080.wav ...
# Converting data\genres\pop\pop.00081.wav ...
# Converting data\genres\pop\pop.00082.wav ...
# Converting data\genres\pop\pop.00083.wav ...
# Converting data\genres\pop\pop.00084.wav ...
# Converting data\genres\pop\pop.00085.wav ...
# Converting data\genres\pop\pop.00086.wav ...
# Converting data\genres\pop\pop.00087.wav ...
# Converting data\genres\pop\pop.00088.wav ...
# Converting data\genres\pop\pop.00089.wav ...
# Converting data\genres\pop\pop.00090.wav ...
# Converting data\genres\pop\pop.00091.wav ...
# Converting data\genres\pop\pop.00092.wav ...
# Converting data\genres\pop\pop.00093.wav ...
# Converting data\genres\pop\pop.00094.wav ...
# Converting data\genres\pop\pop.00095.wav ...
# Converting data\genres\pop\pop.00096.wav ...
# Converting data\genres\pop\pop.00097.wav ...
# Converting data\genres\pop\pop.00098.wav ...
# Converting data\genres\pop\pop.00099.wav ...
# Converting data\genres\reggae\reggae.00000.wav ...
# Converting data\genres\reggae\reggae.00001.wav ...
# Converting data\genres\reggae\reggae.00002.wav ...
# Converting data\genres\reggae\reggae.00003.wav ...
# Converting data\genres\reggae\reggae.00004.wav ...
# Converting data\genres\reggae\reggae.00005.wav ...
# Converting data\genres\reggae\reggae.00006.wav ...
# Converting data\genres\reggae\reggae.00007.wav ...
# Converting data\genres\reggae\reggae.00008.wav ...
# Converting data\genres\reggae\reggae.00009.wav ...
# Converting data\genres\reggae\reggae.00010.wav ...
# Converting data\genres\reggae\reggae.00011.wav ...
# Converting data\genres\reggae\reggae.00012.wav ...
# Converting data\genres\reggae\reggae.00013.wav ...
# Converting data\genres\reggae\reggae.00014.wav ...
# Converting data\genres\reggae\reggae.00015.wav ...
# Converting data\genres\reggae\reggae.00016.wav ...
# Converting data\genres\reggae\reggae.00017.wav ...
# Converting data\genres\reggae\reggae.00018.wav ...
# Converting data\genres\reggae\reggae.00019.wav ...
# Converting data\genres\reggae\reggae.00020.wav ...
# Converting data\genres\reggae\reggae.00021.wav ...
# Converting data\genres\reggae\reggae.00022.wav ...
# Converting data\genres\reggae\reggae.00023.wav ...
# Converting data\genres\reggae\reggae.00024.wav ...
# Converting data\genres\reggae\reggae.00025.wav ...
# Converting data\genres\reggae\reggae.00026.wav ...
# Converting data\genres\reggae\reggae.00027.wav ...
# Converting data\genres\reggae\reggae.00028.wav ...
# Converting data\genres\reggae\reggae.00029.wav ...
# Converting data\genres\reggae\reggae.00030.wav ...
# Converting data\genres\reggae\reggae.00031.wav ...
# Converting data\genres\reggae\reggae.00032.wav ...
# Converting data\genres\reggae\reggae.00033.wav ...
# Converting data\genres\reggae\reggae.00034.wav ...
# Converting data\genres\reggae\reggae.00035.wav ...
# Converting data\genres\reggae\reggae.00036.wav ...
# Converting data\genres\reggae\reggae.00037.wav ...
# Converting data\genres\reggae\reggae.00038.wav ...
# Converting data\genres\reggae\reggae.00039.wav ...
# Converting data\genres\reggae\reggae.00040.wav ...
# Converting data\genres\reggae\reggae.00041.wav ...
# Converting data\genres\reggae\reggae.00042.wav ...
# Converting data\genres\reggae\reggae.00043.wav ...
# Converting data\genres\reggae\reggae.00044.wav ...
# Converting data\genres\reggae\reggae.00045.wav ...
# Converting data\genres\reggae\reggae.00046.wav ...
# Converting data\genres\reggae\reggae.00047.wav ...
# Converting data\genres\reggae\reggae.00048.wav ...
# Converting data\genres\reggae\reggae.00049.wav ...
# Converting data\genres\reggae\reggae.00050.wav ...
# Converting data\genres\reggae\reggae.00051.wav ...
# Converting data\genres\reggae\reggae.00052.wav ...
# Converting data\genres\reggae\reggae.00053.wav ...
# Converting data\genres\reggae\reggae.00054.wav ...
# Converting data\genres\reggae\reggae.00055.wav ...
# Converting data\genres\reggae\reggae.00056.wav ...
# Converting data\genres\reggae\reggae.00057.wav ...
# Converting data\genres\reggae\reggae.00058.wav ...
# Converting data\genres\reggae\reggae.00059.wav ...
# Converting data\genres\reggae\reggae.00060.wav ...
# Converting data\genres\reggae\reggae.00061.wav ...
# Converting data\genres\reggae\reggae.00062.wav ...
# Converting data\genres\reggae\reggae.00063.wav ...
# Converting data\genres\reggae\reggae.00064.wav ...
# Converting data\genres\reggae\reggae.00065.wav ...
# Converting data\genres\reggae\reggae.00066.wav ...
# Converting data\genres\reggae\reggae.00067.wav ...
# Converting data\genres\reggae\reggae.00068.wav ...
# Converting data\genres\reggae\reggae.00069.wav ...
# Converting data\genres\reggae\reggae.00070.wav ...
# Converting data\genres\reggae\reggae.00071.wav ...
# Converting data\genres\reggae\reggae.00072.wav ...
# Converting data\genres\reggae\reggae.00073.wav ...
# Converting data\genres\reggae\reggae.00074.wav ...
# Converting data\genres\reggae\reggae.00075.wav ...
# Converting data\genres\reggae\reggae.00076.wav ...
# Converting data\genres\reggae\reggae.00077.wav ...
# Converting data\genres\reggae\reggae.00078.wav ...
# Converting data\genres\reggae\reggae.00079.wav ...
# Converting data\genres\reggae\reggae.00080.wav ...
# Converting data\genres\reggae\reggae.00081.wav ...
# Converting data\genres\reggae\reggae.00082.wav ...
# Converting data\genres\reggae\reggae.00083.wav ...
# Converting data\genres\reggae\reggae.00084.wav ...
# Converting data\genres\reggae\reggae.00085.wav ...
# Converting data\genres\reggae\reggae.00086.wav ...
# Converting data\genres\reggae\reggae.00087.wav ...
# Converting data\genres\reggae\reggae.00088.wav ...
# Converting data\genres\reggae\reggae.00089.wav ...
# Converting data\genres\reggae\reggae.00090.wav ...
# Converting data\genres\reggae\reggae.00091.wav ...
# Converting data\genres\reggae\reggae.00092.wav ...
# Converting data\genres\reggae\reggae.00093.wav ...
# Converting data\genres\reggae\reggae.00094.wav ...
# Converting data\genres\reggae\reggae.00095.wav ...
# Converting data\genres\reggae\reggae.00096.wav ...
# Converting data\genres\reggae\reggae.00097.wav ...
# Converting data\genres\reggae\reggae.00098.wav ...
# Converting data\genres\reggae\reggae.00099.wav ...
# Converting data\genres\rock\rock.00000.wav ...
# Converting data\genres\rock\rock.00001.wav ...
# Converting data\genres\rock\rock.00002.wav ...
# Converting data\genres\rock\rock.00003.wav ...
# Converting data\genres\rock\rock.00004.wav ...
# Converting data\genres\rock\rock.00005.wav ...
# Converting data\genres\rock\rock.00006.wav ...
# Converting data\genres\rock\rock.00007.wav ...
# Converting data\genres\rock\rock.00008.wav ...
# Converting data\genres\rock\rock.00009.wav ...
# Converting data\genres\rock\rock.00010.wav ...
# Converting data\genres\rock\rock.00011.wav ...
# Converting data\genres\rock\rock.00012.wav ...
# Converting data\genres\rock\rock.00013.wav ...
# Converting data\genres\rock\rock.00014.wav ...
# Converting data\genres\rock\rock.00015.wav ...
# Converting data\genres\rock\rock.00016.wav ...
# Converting data\genres\rock\rock.00017.wav ...
# Converting data\genres\rock\rock.00018.wav ...
# Converting data\genres\rock\rock.00019.wav ...
# Converting data\genres\rock\rock.00020.wav ...
# Converting data\genres\rock\rock.00021.wav ...
# Converting data\genres\rock\rock.00022.wav ...
# Converting data\genres\rock\rock.00023.wav ...
# Converting data\genres\rock\rock.00024.wav ...
# Converting data\genres\rock\rock.00025.wav ...
# Converting data\genres\rock\rock.00026.wav ...
# Converting data\genres\rock\rock.00027.wav ...
# Converting data\genres\rock\rock.00028.wav ...
# Converting data\genres\rock\rock.00029.wav ...
# Converting data\genres\rock\rock.00030.wav ...
# Converting data\genres\rock\rock.00031.wav ...
# Converting data\genres\rock\rock.00032.wav ...
# Converting data\genres\rock\rock.00033.wav ...
# Converting data\genres\rock\rock.00034.wav ...
# Converting data\genres\rock\rock.00035.wav ...
# Converting data\genres\rock\rock.00036.wav ...
# Converting data\genres\rock\rock.00037.wav ...
# Converting data\genres\rock\rock.00038.wav ...
# Converting data\genres\rock\rock.00039.wav ...
# Converting data\genres\rock\rock.00040.wav ...
# Converting data\genres\rock\rock.00041.wav ...
# Converting data\genres\rock\rock.00042.wav ...
# Converting data\genres\rock\rock.00043.wav ...
# Converting data\genres\rock\rock.00044.wav ...
# Converting data\genres\rock\rock.00045.wav ...
# Converting data\genres\rock\rock.00046.wav ...
# Converting data\genres\rock\rock.00047.wav ...
# Converting data\genres\rock\rock.00048.wav ...
# Converting data\genres\rock\rock.00049.wav ...
# Converting data\genres\rock\rock.00050.wav ...
# Converting data\genres\rock\rock.00051.wav ...
# Converting data\genres\rock\rock.00052.wav ...
# Converting data\genres\rock\rock.00053.wav ...
# Converting data\genres\rock\rock.00054.wav ...
# Converting data\genres\rock\rock.00055.wav ...
# Converting data\genres\rock\rock.00056.wav ...
# Converting data\genres\rock\rock.00057.wav ...
# Converting data\genres\rock\rock.00058.wav ...
# Converting data\genres\rock\rock.00059.wav ...
# Converting data\genres\rock\rock.00060.wav ...
# Converting data\genres\rock\rock.00061.wav ...
# Converting data\genres\rock\rock.00062.wav ...
# Converting data\genres\rock\rock.00063.wav ...
# Converting data\genres\rock\rock.00064.wav ...
# Converting data\genres\rock\rock.00065.wav ...
# Converting data\genres\rock\rock.00066.wav ...
# Converting data\genres\rock\rock.00067.wav ...
# Converting data\genres\rock\rock.00068.wav ...
# Converting data\genres\rock\rock.00069.wav ...
# Converting data\genres\rock\rock.00070.wav ...
# Converting data\genres\rock\rock.00071.wav ...
# Converting data\genres\rock\rock.00072.wav ...
# Converting data\genres\rock\rock.00073.wav ...
# Converting data\genres\rock\rock.00074.wav ...
# Converting data\genres\rock\rock.00075.wav ...
# Converting data\genres\rock\rock.00076.wav ...
# Converting data\genres\rock\rock.00077.wav ...
# Converting data\genres\rock\rock.00078.wav ...
# Converting data\genres\rock\rock.00079.wav ...
# Converting data\genres\rock\rock.00080.wav ...
# Converting data\genres\rock\rock.00081.wav ...
# Converting data\genres\rock\rock.00082.wav ...
# Converting data\genres\rock\rock.00083.wav ...
# Converting data\genres\rock\rock.00084.wav ...
# Converting data\genres\rock\rock.00085.wav ...
# Converting data\genres\rock\rock.00086.wav ...
# Converting data\genres\rock\rock.00087.wav ...
# Converting data\genres\rock\rock.00088.wav ...
# Converting data\genres\rock\rock.00089.wav ...
# Converting data\genres\rock\rock.00090.wav ...
# Converting data\genres\rock\rock.00091.wav ...
# Converting data\genres\rock\rock.00092.wav ...
# Converting data\genres\rock\rock.00093.wav ...
# Converting data\genres\rock\rock.00094.wav ...
# Converting data\genres\rock\rock.00095.wav ...
# Converting data\genres\rock\rock.00096.wav ...
# Converting data\genres\rock\rock.00097.wav ...
# Converting data\genres\rock\rock.00098.wav ...
# Converting data\genres\rock\rock.00099.wav ...

# %%
def read_fft(genre_list, base_dir=GENRE_DIR):
    X = []
    y = []
    for label, genre in enumerate(genre_list):
        genre_dir = Path(base_dir) / genre
        for fn in genre_dir.glob("*.fft.npy"):
            fft_features = np.load(fn)

            X.append(fft_features[:1000])
            y.append(label)

    return np.array(X), np.array(y)

# %% [markdown]
# ## Training the FFT-based classifier

# %% [markdown]
# Creating the model...

# %%
from sklearn.linear_model.logistic import LogisticRegression

def create_model():
    return LogisticRegression()

# %%
from collections import defaultdict

from sklearn.metrics import precision_recall_curve, roc_curve, confusion_matrix
from sklearn.metrics import auc
from sklearn.model_selection import ShuffleSplit

def train_model(clf_factory, X, Y, name, plot=False):
    labels = np.unique(Y)

    cv = ShuffleSplit(n_splits=1, test_size=0.3, random_state=0)

    train_errors = []
    test_errors = []

    scores = []
    pr_scores = defaultdict(list)
    precisions, recalls, thresholds = defaultdict(list), defaultdict(list), defaultdict(list)

    roc_scores = defaultdict(list)
    tprs = defaultdict(list)
    fprs = defaultdict(list)

    clfs = []  # just to later get the median

    cms = []

    for train, test in cv.split(X, Y):
        X_train, y_train = X[train], Y[train]
        X_test, y_test = X[test], Y[test]

        clf = clf_factory()
        clf.fit(X_train, y_train)
        clfs.append(clf)

        train_score = clf.score(X_train, y_train)
        test_score = clf.score(X_test, y_test)
        scores.append(test_score)

        train_errors.append(1 - train_score)
        test_errors.append(1 - test_score)

        y_pred = clf.predict(X_test)
        cm = confusion_matrix(y_test, y_pred)
        cms.append(cm)

        for label in labels:
            y_label_test = np.asarray(y_test == label, dtype=int)
            proba = clf.predict_proba(X_test)
            proba_label = proba[:, label]

            precision, recall, pr_thresholds = precision_recall_curve(
                y_label_test, proba_label)
            pr_scores[label].append(auc(recall, precision))
            precisions[label].append(precision)
            recalls[label].append(recall)
            thresholds[label].append(pr_thresholds)

            fpr, tpr, roc_thresholds = roc_curve(y_label_test, proba_label)
            roc_scores[label].append(auc(fpr, tpr))
            tprs[label].append(tpr)
            fprs[label].append(fpr)

    if plot:
        for idx, label in enumerate(labels):
            print("Plotting %s" % GENRES[label])
            scores_to_sort = roc_scores[label]
            median = np.argsort(scores_to_sort)[len(scores_to_sort) // 2]

            desc = "%s %s" % (name, GENRES[label])
            plot_pr(pr_scores[label][median], desc, precisions[label][median],
                    recalls[label][median], label='%s vs rest' % GENRES[label], plot_nr=plot+idx)
            plot_roc(roc_scores[label][median], desc, tprs[label][median],
                     fprs[label][median], label='%s vs rest' % GENRES[label], plot_nr=plot+len(labels)+idx)

    all_pr_scores = np.asarray(list(pr_scores.values())).flatten()
    #import pdb;pdb.set_trace()
    summary = (np.mean(scores), np.std(scores),
               np.mean(all_pr_scores), np.std(all_pr_scores))
    print("%.3f\t%.3f\t%.3f\t%.3f\t" % summary)

    return np.mean(train_errors), np.mean(test_errors), np.asarray(cms)

# %%
def plot_confusion_matrix(cm, genre_list, name, title, plot_nr=None):
    plt.figure(num=None, figsize=(5, 4), dpi=DPI)
    plt.matshow(cm, fignum=False, cmap='Blues', vmin=0, vmax=1.0)
    ax = plt.axes()
    ax.set_xticks(range(len(genre_list)))
    ax.set_xticklabels(genre_list)
    ax.xaxis.set_ticks_position("bottom")
    ax.set_yticks(range(len(genre_list)))
    ax.set_yticklabels(genre_list)
    ax.tick_params(axis='both', which='both', bottom='off',  left='off')
    plt.title(title)
    plt.colorbar()
    plt.grid(False)
    plt.xlabel('Predicted class')
    plt.ylabel('True class')
    if plot_nr is not None:
        save_png('%i_confusion_%s' % (plot_nr, name))

# %%
X, Y = read_fft(GENRES)

train_avg, test_avg, cms = train_model(create_model, X, Y, "Log Reg FFT", plot=5)
# Out:
# C:\local\Anaconda3-4.1.1-Windows-x86_64\lib\site-packages\sklearn\linear_model\base.py:340: RuntimeWarning: overflow encountered in exp
#   np.exp(prob, prob)
# Plotting classical
# No handles with labels found to put in legend.
# Plotting jazz
# No handles with labels found to put in legend.
# Plotting country
# No handles with labels found to put in legend.
# Plotting pop
# No handles with labels found to put in legend.
# Plotting rock
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Plotting metal
# 0.406	0.000	0.322	0.122

# %%
cm_avg = np.mean(cms, axis=0)
cm_norm = cm_avg / np.sum(cm_avg, axis=0)

plot_confusion_matrix(cm_norm, GENRES, "fft", "Confusion matrix of an FFT based classifier", 17)
# Out:
# C:\local\Anaconda3-4.1.1-Windows-x86_64\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %% [markdown]
# # Improving classification performance with Mel Frequency Cepstral Coefficients

# %%
from python_speech_features import mfcc

fn = Path(GENRE_DIR) / 'jazz' / 'jazz.00000.wav'
sample_rate, X = scipy.io.wavfile.read(fn)
ceps = mfcc(X)
print(ceps.shape)
# Out:
# (4135, 13)

# %%
num_ceps = len(ceps)
np.mean(ceps[int(num_ceps*0.1):int(num_ceps*0.9)], axis=0)
# Out:
# array([ 16.43787597,   7.44767565, -13.48062285,  -7.49451887,
#         -8.14466849,  -4.79407047,  -5.53101133,  -5.42776074,
#         -8.69278344,  -6.41223865,  -3.01527269,  -2.75974429,  -3.61836327])

# %%
np.std(ceps[int(num_ceps*0.1):int(num_ceps*0.9)], axis=0)
# Out:
# array([  2.35924851,  12.06182075,   9.8524351 ,   6.17551375,
#          6.88436778,   6.98513479,   8.53439104,   7.27414944,
#          8.5409396 ,   8.99238561,   9.18711851,   8.83647839,   8.49855748])

# %% [markdown]
# ## Generating MFCC features

# %%
def create_ceps(fn):
    sample_rate, X = scipy.io.wavfile.read(fn)
    np.save(Path(fn).with_suffix('.ceps'), mfcc(X))

for wav_fn in Path(GENRE_DIR).glob('**/*.wav'):
    print('Converting %s ...' % str(wav_fn))
    create_ceps(wav_fn)
# Out:
# Converting data\genres\blues\blues.00000.wav ...
# Converting data\genres\blues\blues.00001.wav ...
# Converting data\genres\blues\blues.00002.wav ...
# Converting data\genres\blues\blues.00003.wav ...
# Converting data\genres\blues\blues.00004.wav ...
# Converting data\genres\blues\blues.00005.wav ...
# Converting data\genres\blues\blues.00006.wav ...
# Converting data\genres\blues\blues.00007.wav ...
# Converting data\genres\blues\blues.00008.wav ...
# Converting data\genres\blues\blues.00009.wav ...
# Converting data\genres\blues\blues.00010.wav ...
# Converting data\genres\blues\blues.00011.wav ...
# Converting data\genres\blues\blues.00012.wav ...
# Converting data\genres\blues\blues.00013.wav ...
# Converting data\genres\blues\blues.00014.wav ...
# Converting data\genres\blues\blues.00015.wav ...
# Converting data\genres\blues\blues.00016.wav ...
# Converting data\genres\blues\blues.00017.wav ...
# Converting data\genres\blues\blues.00018.wav ...
# Converting data\genres\blues\blues.00019.wav ...
# Converting data\genres\blues\blues.00020.wav ...
# Converting data\genres\blues\blues.00021.wav ...
# Converting data\genres\blues\blues.00022.wav ...
# Converting data\genres\blues\blues.00023.wav ...
# Converting data\genres\blues\blues.00024.wav ...
# Converting data\genres\blues\blues.00025.wav ...
# Converting data\genres\blues\blues.00026.wav ...
# Converting data\genres\blues\blues.00027.wav ...
# Converting data\genres\blues\blues.00028.wav ...
# Converting data\genres\blues\blues.00029.wav ...
# Converting data\genres\blues\blues.00030.wav ...
# Converting data\genres\blues\blues.00031.wav ...
# Converting data\genres\blues\blues.00032.wav ...
# Converting data\genres\blues\blues.00033.wav ...
# Converting data\genres\blues\blues.00034.wav ...
# Converting data\genres\blues\blues.00035.wav ...
# Converting data\genres\blues\blues.00036.wav ...
# Converting data\genres\blues\blues.00037.wav ...
# Converting data\genres\blues\blues.00038.wav ...
# Converting data\genres\blues\blues.00039.wav ...
# Converting data\genres\blues\blues.00040.wav ...
# Converting data\genres\blues\blues.00041.wav ...
# Converting data\genres\blues\blues.00042.wav ...
# Converting data\genres\blues\blues.00043.wav ...
# Converting data\genres\blues\blues.00044.wav ...
# Converting data\genres\blues\blues.00045.wav ...
# Converting data\genres\blues\blues.00046.wav ...
# Converting data\genres\blues\blues.00047.wav ...
# Converting data\genres\blues\blues.00048.wav ...
# Converting data\genres\blues\blues.00049.wav ...
# Converting data\genres\blues\blues.00050.wav ...
# Converting data\genres\blues\blues.00051.wav ...
# Converting data\genres\blues\blues.00052.wav ...
# Converting data\genres\blues\blues.00053.wav ...
# Converting data\genres\blues\blues.00054.wav ...
# Converting data\genres\blues\blues.00055.wav ...
# Converting data\genres\blues\blues.00056.wav ...
# Converting data\genres\blues\blues.00057.wav ...
# Converting data\genres\blues\blues.00058.wav ...
# Converting data\genres\blues\blues.00059.wav ...
# Converting data\genres\blues\blues.00060.wav ...
# Converting data\genres\blues\blues.00061.wav ...
# Converting data\genres\blues\blues.00062.wav ...
# Converting data\genres\blues\blues.00063.wav ...
# Converting data\genres\blues\blues.00064.wav ...
# Converting data\genres\blues\blues.00065.wav ...
# Converting data\genres\blues\blues.00066.wav ...
# Converting data\genres\blues\blues.00067.wav ...
# Converting data\genres\blues\blues.00068.wav ...
# Converting data\genres\blues\blues.00069.wav ...
# Converting data\genres\blues\blues.00070.wav ...
# Converting data\genres\blues\blues.00071.wav ...
# Converting data\genres\blues\blues.00072.wav ...
# Converting data\genres\blues\blues.00073.wav ...
# Converting data\genres\blues\blues.00074.wav ...
# Converting data\genres\blues\blues.00075.wav ...
# Converting data\genres\blues\blues.00076.wav ...
# Converting data\genres\blues\blues.00077.wav ...
# Converting data\genres\blues\blues.00078.wav ...
# Converting data\genres\blues\blues.00079.wav ...
# Converting data\genres\blues\blues.00080.wav ...
# Converting data\genres\blues\blues.00081.wav ...
# Converting data\genres\blues\blues.00082.wav ...
# Converting data\genres\blues\blues.00083.wav ...
# Converting data\genres\blues\blues.00084.wav ...
# Converting data\genres\blues\blues.00085.wav ...
# Converting data\genres\blues\blues.00086.wav ...
# Converting data\genres\blues\blues.00087.wav ...
# Converting data\genres\blues\blues.00088.wav ...
# Converting data\genres\blues\blues.00089.wav ...
# Converting data\genres\blues\blues.00090.wav ...
# Converting data\genres\blues\blues.00091.wav ...
# Converting data\genres\blues\blues.00092.wav ...
# Converting data\genres\blues\blues.00093.wav ...
# Converting data\genres\blues\blues.00094.wav ...
# Converting data\genres\blues\blues.00095.wav ...
# Converting data\genres\blues\blues.00096.wav ...
# Converting data\genres\blues\blues.00097.wav ...
# Converting data\genres\blues\blues.00098.wav ...
# Converting data\genres\blues\blues.00099.wav ...
# Converting data\genres\classical\classical.00000.wav ...
# Converting data\genres\classical\classical.00001.wav ...
# Converting data\genres\classical\classical.00002.wav ...
# Converting data\genres\classical\classical.00003.wav ...
# Converting data\genres\classical\classical.00004.wav ...
# Converting data\genres\classical\classical.00005.wav ...
# Converting data\genres\classical\classical.00006.wav ...
# Converting data\genres\classical\classical.00007.wav ...
# Converting data\genres\classical\classical.00008.wav ...
# Converting data\genres\classical\classical.00009.wav ...
# Converting data\genres\classical\classical.00010.wav ...
# Converting data\genres\classical\classical.00011.wav ...
# Converting data\genres\classical\classical.00012.wav ...
# Converting data\genres\classical\classical.00013.wav ...
# Converting data\genres\classical\classical.00014.wav ...
# Converting data\genres\classical\classical.00015.wav ...
# Converting data\genres\classical\classical.00016.wav ...
# Converting data\genres\classical\classical.00017.wav ...
# Converting data\genres\classical\classical.00018.wav ...
# Converting data\genres\classical\classical.00019.wav ...
# Converting data\genres\classical\classical.00020.wav ...
# Converting data\genres\classical\classical.00021.wav ...
# Converting data\genres\classical\classical.00022.wav ...
# Converting data\genres\classical\classical.00023.wav ...
# Converting data\genres\classical\classical.00024.wav ...
# Converting data\genres\classical\classical.00025.wav ...
# Converting data\genres\classical\classical.00026.wav ...
# Converting data\genres\classical\classical.00027.wav ...
# Converting data\genres\classical\classical.00028.wav ...
# Converting data\genres\classical\classical.00029.wav ...
# Converting data\genres\classical\classical.00030.wav ...
# Converting data\genres\classical\classical.00031.wav ...
# Converting data\genres\classical\classical.00032.wav ...
# Converting data\genres\classical\classical.00033.wav ...
# Converting data\genres\classical\classical.00034.wav ...
# Converting data\genres\classical\classical.00035.wav ...
# Converting data\genres\classical\classical.00036.wav ...
# Converting data\genres\classical\classical.00037.wav ...
# Converting data\genres\classical\classical.00038.wav ...
# Converting data\genres\classical\classical.00039.wav ...
# Converting data\genres\classical\classical.00040.wav ...
# Converting data\genres\classical\classical.00041.wav ...
# Converting data\genres\classical\classical.00042.wav ...
# Converting data\genres\classical\classical.00043.wav ...
# Converting data\genres\classical\classical.00044.wav ...
# Converting data\genres\classical\classical.00045.wav ...
# Converting data\genres\classical\classical.00046.wav ...
# Converting data\genres\classical\classical.00047.wav ...
# Converting data\genres\classical\classical.00048.wav ...
# Converting data\genres\classical\classical.00049.wav ...
# Converting data\genres\classical\classical.00050.wav ...
# Converting data\genres\classical\classical.00051.wav ...
# Converting data\genres\classical\classical.00052.wav ...
# Converting data\genres\classical\classical.00053.wav ...
# Converting data\genres\classical\classical.00054.wav ...
# Converting data\genres\classical\classical.00055.wav ...
# Converting data\genres\classical\classical.00056.wav ...
# Converting data\genres\classical\classical.00057.wav ...
# Converting data\genres\classical\classical.00058.wav ...
# Converting data\genres\classical\classical.00059.wav ...
# Converting data\genres\classical\classical.00060.wav ...
# Converting data\genres\classical\classical.00061.wav ...
# Converting data\genres\classical\classical.00062.wav ...
# Converting data\genres\classical\classical.00063.wav ...
# Converting data\genres\classical\classical.00064.wav ...
# Converting data\genres\classical\classical.00065.wav ...
# Converting data\genres\classical\classical.00066.wav ...
# Converting data\genres\classical\classical.00067.wav ...
# Converting data\genres\classical\classical.00068.wav ...
# Converting data\genres\classical\classical.00069.wav ...
# Converting data\genres\classical\classical.00070.wav ...
# Converting data\genres\classical\classical.00071.wav ...
# Converting data\genres\classical\classical.00072.wav ...
# Converting data\genres\classical\classical.00073.wav ...
# Converting data\genres\classical\classical.00074.wav ...
# Converting data\genres\classical\classical.00075.wav ...
# Converting data\genres\classical\classical.00076.wav ...
# Converting data\genres\classical\classical.00077.wav ...
# Converting data\genres\classical\classical.00078.wav ...
# Converting data\genres\classical\classical.00079.wav ...
# Converting data\genres\classical\classical.00080.wav ...
# Converting data\genres\classical\classical.00081.wav ...
# Converting data\genres\classical\classical.00082.wav ...
# Converting data\genres\classical\classical.00083.wav ...
# Converting data\genres\classical\classical.00084.wav ...
# Converting data\genres\classical\classical.00085.wav ...
# Converting data\genres\classical\classical.00086.wav ...
# Converting data\genres\classical\classical.00087.wav ...
# Converting data\genres\classical\classical.00088.wav ...
# Converting data\genres\classical\classical.00089.wav ...
# Converting data\genres\classical\classical.00090.wav ...
# Converting data\genres\classical\classical.00091.wav ...
# Converting data\genres\classical\classical.00092.wav ...
# Converting data\genres\classical\classical.00093.wav ...
# Converting data\genres\classical\classical.00094.wav ...
# Converting data\genres\classical\classical.00095.wav ...
# Converting data\genres\classical\classical.00096.wav ...
# Converting data\genres\classical\classical.00097.wav ...
# Converting data\genres\classical\classical.00098.wav ...
# Converting data\genres\classical\classical.00099.wav ...
# Converting data\genres\country\country.00000.wav ...
# Converting data\genres\country\country.00001.wav ...
# Converting data\genres\country\country.00002.wav ...
# Converting data\genres\country\country.00003.wav ...
# Converting data\genres\country\country.00004.wav ...
# Converting data\genres\country\country.00005.wav ...
# Converting data\genres\country\country.00006.wav ...
# Converting data\genres\country\country.00007.wav ...
# Converting data\genres\country\country.00008.wav ...
# Converting data\genres\country\country.00009.wav ...
# Converting data\genres\country\country.00010.wav ...
# Converting data\genres\country\country.00011.wav ...
# Converting data\genres\country\country.00012.wav ...
# Converting data\genres\country\country.00013.wav ...
# Converting data\genres\country\country.00014.wav ...
# Converting data\genres\country\country.00015.wav ...
# Converting data\genres\country\country.00016.wav ...
# Converting data\genres\country\country.00017.wav ...
# Converting data\genres\country\country.00018.wav ...
# Converting data\genres\country\country.00019.wav ...
# Converting data\genres\country\country.00020.wav ...
# Converting data\genres\country\country.00021.wav ...
# Converting data\genres\country\country.00022.wav ...
# Converting data\genres\country\country.00023.wav ...
# Converting data\genres\country\country.00024.wav ...
# Converting data\genres\country\country.00025.wav ...
# Converting data\genres\country\country.00026.wav ...
# Converting data\genres\country\country.00027.wav ...
# Converting data\genres\country\country.00028.wav ...
# Converting data\genres\country\country.00029.wav ...
# Converting data\genres\country\country.00030.wav ...
# Converting data\genres\country\country.00031.wav ...
# Converting data\genres\country\country.00032.wav ...
# Converting data\genres\country\country.00033.wav ...
# Converting data\genres\country\country.00034.wav ...
# Converting data\genres\country\country.00035.wav ...
# Converting data\genres\country\country.00036.wav ...
# Converting data\genres\country\country.00037.wav ...
# Converting data\genres\country\country.00038.wav ...
# Converting data\genres\country\country.00039.wav ...
# Converting data\genres\country\country.00040.wav ...
# Converting data\genres\country\country.00041.wav ...
# Converting data\genres\country\country.00042.wav ...
# Converting data\genres\country\country.00043.wav ...
# Converting data\genres\country\country.00044.wav ...
# Converting data\genres\country\country.00045.wav ...
# Converting data\genres\country\country.00046.wav ...
# Converting data\genres\country\country.00047.wav ...
# Converting data\genres\country\country.00048.wav ...
# Converting data\genres\country\country.00049.wav ...
# Converting data\genres\country\country.00050.wav ...
# Converting data\genres\country\country.00051.wav ...
# Converting data\genres\country\country.00052.wav ...
# Converting data\genres\country\country.00053.wav ...
# Converting data\genres\country\country.00054.wav ...
# Converting data\genres\country\country.00055.wav ...
# Converting data\genres\country\country.00056.wav ...
# Converting data\genres\country\country.00057.wav ...
# Converting data\genres\country\country.00058.wav ...
# Converting data\genres\country\country.00059.wav ...
# Converting data\genres\country\country.00060.wav ...
# Converting data\genres\country\country.00061.wav ...
# Converting data\genres\country\country.00062.wav ...
# Converting data\genres\country\country.00063.wav ...
# Converting data\genres\country\country.00064.wav ...
# Converting data\genres\country\country.00065.wav ...
# Converting data\genres\country\country.00066.wav ...
# Converting data\genres\country\country.00067.wav ...
# Converting data\genres\country\country.00068.wav ...
# Converting data\genres\country\country.00069.wav ...
# Converting data\genres\country\country.00070.wav ...
# Converting data\genres\country\country.00071.wav ...
# Converting data\genres\country\country.00072.wav ...
# Converting data\genres\country\country.00073.wav ...
# Converting data\genres\country\country.00074.wav ...
# Converting data\genres\country\country.00075.wav ...
# Converting data\genres\country\country.00076.wav ...
# Converting data\genres\country\country.00077.wav ...
# Converting data\genres\country\country.00078.wav ...
# Converting data\genres\country\country.00079.wav ...
# Converting data\genres\country\country.00080.wav ...
# Converting data\genres\country\country.00081.wav ...
# Converting data\genres\country\country.00082.wav ...
# Converting data\genres\country\country.00083.wav ...
# Converting data\genres\country\country.00084.wav ...
# Converting data\genres\country\country.00085.wav ...
# Converting data\genres\country\country.00086.wav ...
# Converting data\genres\country\country.00087.wav ...
# Converting data\genres\country\country.00088.wav ...
# Converting data\genres\country\country.00089.wav ...
# Converting data\genres\country\country.00090.wav ...
# Converting data\genres\country\country.00091.wav ...
# Converting data\genres\country\country.00092.wav ...
# Converting data\genres\country\country.00093.wav ...
# Converting data\genres\country\country.00094.wav ...
# Converting data\genres\country\country.00095.wav ...
# Converting data\genres\country\country.00096.wav ...
# Converting data\genres\country\country.00097.wav ...
# Converting data\genres\country\country.00098.wav ...
# Converting data\genres\country\country.00099.wav ...
# Converting data\genres\disco\disco.00000.wav ...
# Converting data\genres\disco\disco.00001.wav ...
# Converting data\genres\disco\disco.00002.wav ...
# Converting data\genres\disco\disco.00003.wav ...
# Converting data\genres\disco\disco.00004.wav ...
# Converting data\genres\disco\disco.00005.wav ...
# Converting data\genres\disco\disco.00006.wav ...
# Converting data\genres\disco\disco.00007.wav ...
# Converting data\genres\disco\disco.00008.wav ...
# Converting data\genres\disco\disco.00009.wav ...
# Converting data\genres\disco\disco.00010.wav ...
# Converting data\genres\disco\disco.00011.wav ...
# Converting data\genres\disco\disco.00012.wav ...
# Converting data\genres\disco\disco.00013.wav ...
# Converting data\genres\disco\disco.00014.wav ...
# Converting data\genres\disco\disco.00015.wav ...
# Converting data\genres\disco\disco.00016.wav ...
# Converting data\genres\disco\disco.00017.wav ...
# Converting data\genres\disco\disco.00018.wav ...
# Converting data\genres\disco\disco.00019.wav ...
# Converting data\genres\disco\disco.00020.wav ...
# Converting data\genres\disco\disco.00021.wav ...
# Converting data\genres\disco\disco.00022.wav ...
# Converting data\genres\disco\disco.00023.wav ...
# Converting data\genres\disco\disco.00024.wav ...
# Converting data\genres\disco\disco.00025.wav ...
# Converting data\genres\disco\disco.00026.wav ...
# Converting data\genres\disco\disco.00027.wav ...
# Converting data\genres\disco\disco.00028.wav ...
# Converting data\genres\disco\disco.00029.wav ...
# Converting data\genres\disco\disco.00030.wav ...
# Converting data\genres\disco\disco.00031.wav ...
# Converting data\genres\disco\disco.00032.wav ...
# Converting data\genres\disco\disco.00033.wav ...
# Converting data\genres\disco\disco.00034.wav ...
# Converting data\genres\disco\disco.00035.wav ...
# Converting data\genres\disco\disco.00036.wav ...
# Converting data\genres\disco\disco.00037.wav ...
# Converting data\genres\disco\disco.00038.wav ...
# Converting data\genres\disco\disco.00039.wav ...
# Converting data\genres\disco\disco.00040.wav ...
# Converting data\genres\disco\disco.00041.wav ...
# Converting data\genres\disco\disco.00042.wav ...
# Converting data\genres\disco\disco.00043.wav ...
# Converting data\genres\disco\disco.00044.wav ...
# Converting data\genres\disco\disco.00045.wav ...
# Converting data\genres\disco\disco.00046.wav ...
# Converting data\genres\disco\disco.00047.wav ...
# Converting data\genres\disco\disco.00048.wav ...
# Converting data\genres\disco\disco.00049.wav ...
# Converting data\genres\disco\disco.00050.wav ...
# Converting data\genres\disco\disco.00051.wav ...
# Converting data\genres\disco\disco.00052.wav ...
# Converting data\genres\disco\disco.00053.wav ...
# Converting data\genres\disco\disco.00054.wav ...
# Converting data\genres\disco\disco.00055.wav ...
# Converting data\genres\disco\disco.00056.wav ...
# Converting data\genres\disco\disco.00057.wav ...
# Converting data\genres\disco\disco.00058.wav ...
# Converting data\genres\disco\disco.00059.wav ...
# Converting data\genres\disco\disco.00060.wav ...
# Converting data\genres\disco\disco.00061.wav ...
# Converting data\genres\disco\disco.00062.wav ...
# Converting data\genres\disco\disco.00063.wav ...
# Converting data\genres\disco\disco.00064.wav ...
# Converting data\genres\disco\disco.00065.wav ...
# Converting data\genres\disco\disco.00066.wav ...
# Converting data\genres\disco\disco.00067.wav ...
# Converting data\genres\disco\disco.00068.wav ...
# Converting data\genres\disco\disco.00069.wav ...
# Converting data\genres\disco\disco.00070.wav ...
# Converting data\genres\disco\disco.00071.wav ...
# Converting data\genres\disco\disco.00072.wav ...
# Converting data\genres\disco\disco.00073.wav ...
# Converting data\genres\disco\disco.00074.wav ...
# Converting data\genres\disco\disco.00075.wav ...
# Converting data\genres\disco\disco.00076.wav ...
# Converting data\genres\disco\disco.00077.wav ...
# Converting data\genres\disco\disco.00078.wav ...
# Converting data\genres\disco\disco.00079.wav ...
# Converting data\genres\disco\disco.00080.wav ...
# Converting data\genres\disco\disco.00081.wav ...
# Converting data\genres\disco\disco.00082.wav ...
# Converting data\genres\disco\disco.00083.wav ...
# Converting data\genres\disco\disco.00084.wav ...
# Converting data\genres\disco\disco.00085.wav ...
# Converting data\genres\disco\disco.00086.wav ...
# Converting data\genres\disco\disco.00087.wav ...
# Converting data\genres\disco\disco.00088.wav ...
# Converting data\genres\disco\disco.00089.wav ...
# Converting data\genres\disco\disco.00090.wav ...
# Converting data\genres\disco\disco.00091.wav ...
# Converting data\genres\disco\disco.00092.wav ...
# Converting data\genres\disco\disco.00093.wav ...
# Converting data\genres\disco\disco.00094.wav ...
# Converting data\genres\disco\disco.00095.wav ...
# Converting data\genres\disco\disco.00096.wav ...
# Converting data\genres\disco\disco.00097.wav ...
# Converting data\genres\disco\disco.00098.wav ...
# Converting data\genres\disco\disco.00099.wav ...
# Converting data\genres\hiphop\hiphop.00000.wav ...
# Converting data\genres\hiphop\hiphop.00001.wav ...
# Converting data\genres\hiphop\hiphop.00002.wav ...
# Converting data\genres\hiphop\hiphop.00003.wav ...
# Converting data\genres\hiphop\hiphop.00004.wav ...
# Converting data\genres\hiphop\hiphop.00005.wav ...
# Converting data\genres\hiphop\hiphop.00006.wav ...
# Converting data\genres\hiphop\hiphop.00007.wav ...
# Converting data\genres\hiphop\hiphop.00008.wav ...
# Converting data\genres\hiphop\hiphop.00009.wav ...
# Converting data\genres\hiphop\hiphop.00010.wav ...
# Converting data\genres\hiphop\hiphop.00011.wav ...
# Converting data\genres\hiphop\hiphop.00012.wav ...
# Converting data\genres\hiphop\hiphop.00013.wav ...
# Converting data\genres\hiphop\hiphop.00014.wav ...
# Converting data\genres\hiphop\hiphop.00015.wav ...
# Converting data\genres\hiphop\hiphop.00016.wav ...
# Converting data\genres\hiphop\hiphop.00017.wav ...
# Converting data\genres\hiphop\hiphop.00018.wav ...
# Converting data\genres\hiphop\hiphop.00019.wav ...
# Converting data\genres\hiphop\hiphop.00020.wav ...
# Converting data\genres\hiphop\hiphop.00021.wav ...
# Converting data\genres\hiphop\hiphop.00022.wav ...
# Converting data\genres\hiphop\hiphop.00023.wav ...
# Converting data\genres\hiphop\hiphop.00024.wav ...
# Converting data\genres\hiphop\hiphop.00025.wav ...
# Converting data\genres\hiphop\hiphop.00026.wav ...
# Converting data\genres\hiphop\hiphop.00027.wav ...
# Converting data\genres\hiphop\hiphop.00028.wav ...
# Converting data\genres\hiphop\hiphop.00029.wav ...
# Converting data\genres\hiphop\hiphop.00030.wav ...
# Converting data\genres\hiphop\hiphop.00031.wav ...
# Converting data\genres\hiphop\hiphop.00032.wav ...
# Converting data\genres\hiphop\hiphop.00033.wav ...
# Converting data\genres\hiphop\hiphop.00034.wav ...
# Converting data\genres\hiphop\hiphop.00035.wav ...
# Converting data\genres\hiphop\hiphop.00036.wav ...
# Converting data\genres\hiphop\hiphop.00037.wav ...
# Converting data\genres\hiphop\hiphop.00038.wav ...
# Converting data\genres\hiphop\hiphop.00039.wav ...
# Converting data\genres\hiphop\hiphop.00040.wav ...
# Converting data\genres\hiphop\hiphop.00041.wav ...
# Converting data\genres\hiphop\hiphop.00042.wav ...
# Converting data\genres\hiphop\hiphop.00043.wav ...
# Converting data\genres\hiphop\hiphop.00044.wav ...
# Converting data\genres\hiphop\hiphop.00045.wav ...
# Converting data\genres\hiphop\hiphop.00046.wav ...
# Converting data\genres\hiphop\hiphop.00047.wav ...
# Converting data\genres\hiphop\hiphop.00048.wav ...
# Converting data\genres\hiphop\hiphop.00049.wav ...
# Converting data\genres\hiphop\hiphop.00050.wav ...
# Converting data\genres\hiphop\hiphop.00051.wav ...
# Converting data\genres\hiphop\hiphop.00052.wav ...
# Converting data\genres\hiphop\hiphop.00053.wav ...
# Converting data\genres\hiphop\hiphop.00054.wav ...
# Converting data\genres\hiphop\hiphop.00055.wav ...
# Converting data\genres\hiphop\hiphop.00056.wav ...
# Converting data\genres\hiphop\hiphop.00057.wav ...
# Converting data\genres\hiphop\hiphop.00058.wav ...
# Converting data\genres\hiphop\hiphop.00059.wav ...
# Converting data\genres\hiphop\hiphop.00060.wav ...
# Converting data\genres\hiphop\hiphop.00061.wav ...
# Converting data\genres\hiphop\hiphop.00062.wav ...
# Converting data\genres\hiphop\hiphop.00063.wav ...
# Converting data\genres\hiphop\hiphop.00064.wav ...
# Converting data\genres\hiphop\hiphop.00065.wav ...
# Converting data\genres\hiphop\hiphop.00066.wav ...
# Converting data\genres\hiphop\hiphop.00067.wav ...
# Converting data\genres\hiphop\hiphop.00068.wav ...
# Converting data\genres\hiphop\hiphop.00069.wav ...
# Converting data\genres\hiphop\hiphop.00070.wav ...
# Converting data\genres\hiphop\hiphop.00071.wav ...
# Converting data\genres\hiphop\hiphop.00072.wav ...
# Converting data\genres\hiphop\hiphop.00073.wav ...
# Converting data\genres\hiphop\hiphop.00074.wav ...
# Converting data\genres\hiphop\hiphop.00075.wav ...
# Converting data\genres\hiphop\hiphop.00076.wav ...
# Converting data\genres\hiphop\hiphop.00077.wav ...
# Converting data\genres\hiphop\hiphop.00078.wav ...
# Converting data\genres\hiphop\hiphop.00079.wav ...
# Converting data\genres\hiphop\hiphop.00080.wav ...
# Converting data\genres\hiphop\hiphop.00081.wav ...
# Converting data\genres\hiphop\hiphop.00082.wav ...
# Converting data\genres\hiphop\hiphop.00083.wav ...
# Converting data\genres\hiphop\hiphop.00084.wav ...
# Converting data\genres\hiphop\hiphop.00085.wav ...
# Converting data\genres\hiphop\hiphop.00086.wav ...
# Converting data\genres\hiphop\hiphop.00087.wav ...
# Converting data\genres\hiphop\hiphop.00088.wav ...
# Converting data\genres\hiphop\hiphop.00089.wav ...
# Converting data\genres\hiphop\hiphop.00090.wav ...
# Converting data\genres\hiphop\hiphop.00091.wav ...
# Converting data\genres\hiphop\hiphop.00092.wav ...
# Converting data\genres\hiphop\hiphop.00093.wav ...
# Converting data\genres\hiphop\hiphop.00094.wav ...
# Converting data\genres\hiphop\hiphop.00095.wav ...
# Converting data\genres\hiphop\hiphop.00096.wav ...
# Converting data\genres\hiphop\hiphop.00097.wav ...
# Converting data\genres\hiphop\hiphop.00098.wav ...
# Converting data\genres\hiphop\hiphop.00099.wav ...
# Converting data\genres\jazz\jazz.00000.wav ...
# Converting data\genres\jazz\jazz.00001.wav ...
# Converting data\genres\jazz\jazz.00002.wav ...
# Converting data\genres\jazz\jazz.00003.wav ...
# Converting data\genres\jazz\jazz.00004.wav ...
# Converting data\genres\jazz\jazz.00005.wav ...
# Converting data\genres\jazz\jazz.00006.wav ...
# Converting data\genres\jazz\jazz.00007.wav ...
# Converting data\genres\jazz\jazz.00008.wav ...
# Converting data\genres\jazz\jazz.00009.wav ...
# Converting data\genres\jazz\jazz.00010.wav ...
# Converting data\genres\jazz\jazz.00011.wav ...
# Converting data\genres\jazz\jazz.00012.wav ...
# Converting data\genres\jazz\jazz.00013.wav ...
# Converting data\genres\jazz\jazz.00014.wav ...
# Converting data\genres\jazz\jazz.00015.wav ...
# Converting data\genres\jazz\jazz.00016.wav ...
# Converting data\genres\jazz\jazz.00017.wav ...
# Converting data\genres\jazz\jazz.00018.wav ...
# Converting data\genres\jazz\jazz.00019.wav ...
# Converting data\genres\jazz\jazz.00020.wav ...
# Converting data\genres\jazz\jazz.00021.wav ...
# Converting data\genres\jazz\jazz.00022.wav ...
# Converting data\genres\jazz\jazz.00023.wav ...
# Converting data\genres\jazz\jazz.00024.wav ...
# Converting data\genres\jazz\jazz.00025.wav ...
# Converting data\genres\jazz\jazz.00026.wav ...
# Converting data\genres\jazz\jazz.00027.wav ...
# Converting data\genres\jazz\jazz.00028.wav ...
# Converting data\genres\jazz\jazz.00029.wav ...
# Converting data\genres\jazz\jazz.00030.wav ...
# Converting data\genres\jazz\jazz.00031.wav ...
# Converting data\genres\jazz\jazz.00032.wav ...
# Converting data\genres\jazz\jazz.00033.wav ...
# Converting data\genres\jazz\jazz.00034.wav ...
# Converting data\genres\jazz\jazz.00035.wav ...
# Converting data\genres\jazz\jazz.00036.wav ...
# Converting data\genres\jazz\jazz.00037.wav ...
# Converting data\genres\jazz\jazz.00038.wav ...
# Converting data\genres\jazz\jazz.00039.wav ...
# Converting data\genres\jazz\jazz.00040.wav ...
# Converting data\genres\jazz\jazz.00041.wav ...
# Converting data\genres\jazz\jazz.00042.wav ...
# Converting data\genres\jazz\jazz.00043.wav ...
# Converting data\genres\jazz\jazz.00044.wav ...
# Converting data\genres\jazz\jazz.00045.wav ...
# Converting data\genres\jazz\jazz.00046.wav ...
# Converting data\genres\jazz\jazz.00047.wav ...
# Converting data\genres\jazz\jazz.00048.wav ...
# Converting data\genres\jazz\jazz.00049.wav ...
# Converting data\genres\jazz\jazz.00050.wav ...
# Converting data\genres\jazz\jazz.00051.wav ...
# Converting data\genres\jazz\jazz.00052.wav ...
# Converting data\genres\jazz\jazz.00053.wav ...
# Converting data\genres\jazz\jazz.00054.wav ...
# Converting data\genres\jazz\jazz.00055.wav ...
# Converting data\genres\jazz\jazz.00056.wav ...
# Converting data\genres\jazz\jazz.00057.wav ...
# Converting data\genres\jazz\jazz.00058.wav ...
# Converting data\genres\jazz\jazz.00059.wav ...
# Converting data\genres\jazz\jazz.00060.wav ...
# Converting data\genres\jazz\jazz.00061.wav ...
# Converting data\genres\jazz\jazz.00062.wav ...
# Converting data\genres\jazz\jazz.00063.wav ...
# Converting data\genres\jazz\jazz.00064.wav ...
# Converting data\genres\jazz\jazz.00065.wav ...
# Converting data\genres\jazz\jazz.00066.wav ...
# Converting data\genres\jazz\jazz.00067.wav ...
# Converting data\genres\jazz\jazz.00068.wav ...
# Converting data\genres\jazz\jazz.00069.wav ...
# Converting data\genres\jazz\jazz.00070.wav ...
# Converting data\genres\jazz\jazz.00071.wav ...
# Converting data\genres\jazz\jazz.00072.wav ...
# Converting data\genres\jazz\jazz.00073.wav ...
# Converting data\genres\jazz\jazz.00074.wav ...
# Converting data\genres\jazz\jazz.00075.wav ...
# Converting data\genres\jazz\jazz.00076.wav ...
# Converting data\genres\jazz\jazz.00077.wav ...
# Converting data\genres\jazz\jazz.00078.wav ...
# Converting data\genres\jazz\jazz.00079.wav ...
# Converting data\genres\jazz\jazz.00080.wav ...
# Converting data\genres\jazz\jazz.00081.wav ...
# Converting data\genres\jazz\jazz.00082.wav ...
# Converting data\genres\jazz\jazz.00083.wav ...
# Converting data\genres\jazz\jazz.00084.wav ...
# Converting data\genres\jazz\jazz.00085.wav ...
# Converting data\genres\jazz\jazz.00086.wav ...
# Converting data\genres\jazz\jazz.00087.wav ...
# Converting data\genres\jazz\jazz.00088.wav ...
# Converting data\genres\jazz\jazz.00089.wav ...
# Converting data\genres\jazz\jazz.00090.wav ...
# Converting data\genres\jazz\jazz.00091.wav ...
# Converting data\genres\jazz\jazz.00092.wav ...
# Converting data\genres\jazz\jazz.00093.wav ...
# Converting data\genres\jazz\jazz.00094.wav ...
# Converting data\genres\jazz\jazz.00095.wav ...
# Converting data\genres\jazz\jazz.00096.wav ...
# Converting data\genres\jazz\jazz.00097.wav ...
# Converting data\genres\jazz\jazz.00098.wav ...
# Converting data\genres\jazz\jazz.00099.wav ...
# Converting data\genres\metal\metal.00000.wav ...
# Converting data\genres\metal\metal.00001.wav ...
# Converting data\genres\metal\metal.00002.wav ...
# Converting data\genres\metal\metal.00003.wav ...
# Converting data\genres\metal\metal.00004.wav ...
# Converting data\genres\metal\metal.00005.wav ...
# Converting data\genres\metal\metal.00006.wav ...
# Converting data\genres\metal\metal.00007.wav ...
# Converting data\genres\metal\metal.00008.wav ...
# Converting data\genres\metal\metal.00009.wav ...
# Converting data\genres\metal\metal.00010.wav ...
# Converting data\genres\metal\metal.00011.wav ...
# Converting data\genres\metal\metal.00012.wav ...
# Converting data\genres\metal\metal.00013.wav ...
# Converting data\genres\metal\metal.00014.wav ...
# Converting data\genres\metal\metal.00015.wav ...
# Converting data\genres\metal\metal.00016.wav ...
# Converting data\genres\metal\metal.00017.wav ...
# Converting data\genres\metal\metal.00018.wav ...
# Converting data\genres\metal\metal.00019.wav ...
# Converting data\genres\metal\metal.00020.wav ...
# Converting data\genres\metal\metal.00021.wav ...
# Converting data\genres\metal\metal.00022.wav ...
# Converting data\genres\metal\metal.00023.wav ...
# Converting data\genres\metal\metal.00024.wav ...
# Converting data\genres\metal\metal.00025.wav ...
# Converting data\genres\metal\metal.00026.wav ...
# Converting data\genres\metal\metal.00027.wav ...
# Converting data\genres\metal\metal.00028.wav ...
# Converting data\genres\metal\metal.00029.wav ...
# Converting data\genres\metal\metal.00030.wav ...
# Converting data\genres\metal\metal.00031.wav ...
# Converting data\genres\metal\metal.00032.wav ...
# Converting data\genres\metal\metal.00033.wav ...
# Converting data\genres\metal\metal.00034.wav ...
# Converting data\genres\metal\metal.00035.wav ...
# Converting data\genres\metal\metal.00036.wav ...
# Converting data\genres\metal\metal.00037.wav ...
# Converting data\genres\metal\metal.00038.wav ...
# Converting data\genres\metal\metal.00039.wav ...
# Converting data\genres\metal\metal.00040.wav ...
# Converting data\genres\metal\metal.00041.wav ...
# Converting data\genres\metal\metal.00042.wav ...
# Converting data\genres\metal\metal.00043.wav ...
# Converting data\genres\metal\metal.00044.wav ...
# Converting data\genres\metal\metal.00045.wav ...
# Converting data\genres\metal\metal.00046.wav ...
# Converting data\genres\metal\metal.00047.wav ...
# Converting data\genres\metal\metal.00048.wav ...
# Converting data\genres\metal\metal.00049.wav ...
# Converting data\genres\metal\metal.00050.wav ...
# Converting data\genres\metal\metal.00051.wav ...
# Converting data\genres\metal\metal.00052.wav ...
# Converting data\genres\metal\metal.00053.wav ...
# Converting data\genres\metal\metal.00054.wav ...
# Converting data\genres\metal\metal.00055.wav ...
# Converting data\genres\metal\metal.00056.wav ...
# Converting data\genres\metal\metal.00057.wav ...
# Converting data\genres\metal\metal.00058.wav ...
# Converting data\genres\metal\metal.00059.wav ...
# Converting data\genres\metal\metal.00060.wav ...
# Converting data\genres\metal\metal.00061.wav ...
# Converting data\genres\metal\metal.00062.wav ...
# Converting data\genres\metal\metal.00063.wav ...
# Converting data\genres\metal\metal.00064.wav ...
# Converting data\genres\metal\metal.00065.wav ...
# Converting data\genres\metal\metal.00066.wav ...
# Converting data\genres\metal\metal.00067.wav ...
# Converting data\genres\metal\metal.00068.wav ...
# Converting data\genres\metal\metal.00069.wav ...
# Converting data\genres\metal\metal.00070.wav ...
# Converting data\genres\metal\metal.00071.wav ...
# Converting data\genres\metal\metal.00072.wav ...
# Converting data\genres\metal\metal.00073.wav ...
# Converting data\genres\metal\metal.00074.wav ...
# Converting data\genres\metal\metal.00075.wav ...
# Converting data\genres\metal\metal.00076.wav ...
# Converting data\genres\metal\metal.00077.wav ...
# Converting data\genres\metal\metal.00078.wav ...
# Converting data\genres\metal\metal.00079.wav ...
# Converting data\genres\metal\metal.00080.wav ...
# Converting data\genres\metal\metal.00081.wav ...
# Converting data\genres\metal\metal.00082.wav ...
# Converting data\genres\metal\metal.00083.wav ...
# Converting data\genres\metal\metal.00084.wav ...
# Converting data\genres\metal\metal.00085.wav ...
# Converting data\genres\metal\metal.00086.wav ...
# Converting data\genres\metal\metal.00087.wav ...
# Converting data\genres\metal\metal.00088.wav ...
# Converting data\genres\metal\metal.00089.wav ...
# Converting data\genres\metal\metal.00090.wav ...
# Converting data\genres\metal\metal.00091.wav ...
# Converting data\genres\metal\metal.00092.wav ...
# Converting data\genres\metal\metal.00093.wav ...
# Converting data\genres\metal\metal.00094.wav ...
# Converting data\genres\metal\metal.00095.wav ...
# Converting data\genres\metal\metal.00096.wav ...
# Converting data\genres\metal\metal.00097.wav ...
# Converting data\genres\metal\metal.00098.wav ...
# Converting data\genres\metal\metal.00099.wav ...
# Converting data\genres\pop\pop.00000.wav ...
# Converting data\genres\pop\pop.00001.wav ...
# Converting data\genres\pop\pop.00002.wav ...
# Converting data\genres\pop\pop.00003.wav ...
# Converting data\genres\pop\pop.00004.wav ...
# Converting data\genres\pop\pop.00005.wav ...
# Converting data\genres\pop\pop.00006.wav ...
# Converting data\genres\pop\pop.00007.wav ...
# Converting data\genres\pop\pop.00008.wav ...
# Converting data\genres\pop\pop.00009.wav ...
# Converting data\genres\pop\pop.00010.wav ...
# Converting data\genres\pop\pop.00011.wav ...
# Converting data\genres\pop\pop.00012.wav ...
# Converting data\genres\pop\pop.00013.wav ...
# Converting data\genres\pop\pop.00014.wav ...
# Converting data\genres\pop\pop.00015.wav ...
# Converting data\genres\pop\pop.00016.wav ...
# Converting data\genres\pop\pop.00017.wav ...
# Converting data\genres\pop\pop.00018.wav ...
# Converting data\genres\pop\pop.00019.wav ...
# Converting data\genres\pop\pop.00020.wav ...
# Converting data\genres\pop\pop.00021.wav ...
# Converting data\genres\pop\pop.00022.wav ...
# Converting data\genres\pop\pop.00023.wav ...
# Converting data\genres\pop\pop.00024.wav ...
# Converting data\genres\pop\pop.00025.wav ...
# Converting data\genres\pop\pop.00026.wav ...
# Converting data\genres\pop\pop.00027.wav ...
# Converting data\genres\pop\pop.00028.wav ...
# Converting data\genres\pop\pop.00029.wav ...
# Converting data\genres\pop\pop.00030.wav ...
# Converting data\genres\pop\pop.00031.wav ...
# Converting data\genres\pop\pop.00032.wav ...
# Converting data\genres\pop\pop.00033.wav ...
# Converting data\genres\pop\pop.00034.wav ...
# Converting data\genres\pop\pop.00035.wav ...
# Converting data\genres\pop\pop.00036.wav ...
# Converting data\genres\pop\pop.00037.wav ...
# Converting data\genres\pop\pop.00038.wav ...
# Converting data\genres\pop\pop.00039.wav ...
# Converting data\genres\pop\pop.00040.wav ...
# Converting data\genres\pop\pop.00041.wav ...
# Converting data\genres\pop\pop.00042.wav ...
# Converting data\genres\pop\pop.00043.wav ...
# Converting data\genres\pop\pop.00044.wav ...
# Converting data\genres\pop\pop.00045.wav ...
# Converting data\genres\pop\pop.00046.wav ...
# Converting data\genres\pop\pop.00047.wav ...
# Converting data\genres\pop\pop.00048.wav ...
# Converting data\genres\pop\pop.00049.wav ...
# Converting data\genres\pop\pop.00050.wav ...
# Converting data\genres\pop\pop.00051.wav ...
# Converting data\genres\pop\pop.00052.wav ...
# Converting data\genres\pop\pop.00053.wav ...
# Converting data\genres\pop\pop.00054.wav ...
# Converting data\genres\pop\pop.00055.wav ...
# Converting data\genres\pop\pop.00056.wav ...
# Converting data\genres\pop\pop.00057.wav ...
# Converting data\genres\pop\pop.00058.wav ...
# Converting data\genres\pop\pop.00059.wav ...
# Converting data\genres\pop\pop.00060.wav ...
# Converting data\genres\pop\pop.00061.wav ...
# Converting data\genres\pop\pop.00062.wav ...
# Converting data\genres\pop\pop.00063.wav ...
# Converting data\genres\pop\pop.00064.wav ...
# Converting data\genres\pop\pop.00065.wav ...
# Converting data\genres\pop\pop.00066.wav ...
# Converting data\genres\pop\pop.00067.wav ...
# Converting data\genres\pop\pop.00068.wav ...
# Converting data\genres\pop\pop.00069.wav ...
# Converting data\genres\pop\pop.00070.wav ...
# Converting data\genres\pop\pop.00071.wav ...
# Converting data\genres\pop\pop.00072.wav ...
# Converting data\genres\pop\pop.00073.wav ...
# Converting data\genres\pop\pop.00074.wav ...
# Converting data\genres\pop\pop.00075.wav ...
# Converting data\genres\pop\pop.00076.wav ...
# Converting data\genres\pop\pop.00077.wav ...
# Converting data\genres\pop\pop.00078.wav ...
# Converting data\genres\pop\pop.00079.wav ...
# Converting data\genres\pop\pop.00080.wav ...
# Converting data\genres\pop\pop.00081.wav ...
# Converting data\genres\pop\pop.00082.wav ...
# Converting data\genres\pop\pop.00083.wav ...
# Converting data\genres\pop\pop.00084.wav ...
# Converting data\genres\pop\pop.00085.wav ...
# Converting data\genres\pop\pop.00086.wav ...
# Converting data\genres\pop\pop.00087.wav ...
# Converting data\genres\pop\pop.00088.wav ...
# Converting data\genres\pop\pop.00089.wav ...
# Converting data\genres\pop\pop.00090.wav ...
# Converting data\genres\pop\pop.00091.wav ...
# Converting data\genres\pop\pop.00092.wav ...
# Converting data\genres\pop\pop.00093.wav ...
# Converting data\genres\pop\pop.00094.wav ...
# Converting data\genres\pop\pop.00095.wav ...
# Converting data\genres\pop\pop.00096.wav ...
# Converting data\genres\pop\pop.00097.wav ...
# Converting data\genres\pop\pop.00098.wav ...
# Converting data\genres\pop\pop.00099.wav ...
# Converting data\genres\reggae\reggae.00000.wav ...
# Converting data\genres\reggae\reggae.00001.wav ...
# Converting data\genres\reggae\reggae.00002.wav ...
# Converting data\genres\reggae\reggae.00003.wav ...
# Converting data\genres\reggae\reggae.00004.wav ...
# Converting data\genres\reggae\reggae.00005.wav ...
# Converting data\genres\reggae\reggae.00006.wav ...
# Converting data\genres\reggae\reggae.00007.wav ...
# Converting data\genres\reggae\reggae.00008.wav ...
# Converting data\genres\reggae\reggae.00009.wav ...
# Converting data\genres\reggae\reggae.00010.wav ...
# Converting data\genres\reggae\reggae.00011.wav ...
# Converting data\genres\reggae\reggae.00012.wav ...
# Converting data\genres\reggae\reggae.00013.wav ...
# Converting data\genres\reggae\reggae.00014.wav ...
# Converting data\genres\reggae\reggae.00015.wav ...
# Converting data\genres\reggae\reggae.00016.wav ...
# Converting data\genres\reggae\reggae.00017.wav ...
# Converting data\genres\reggae\reggae.00018.wav ...
# Converting data\genres\reggae\reggae.00019.wav ...
# Converting data\genres\reggae\reggae.00020.wav ...
# Converting data\genres\reggae\reggae.00021.wav ...
# Converting data\genres\reggae\reggae.00022.wav ...
# Converting data\genres\reggae\reggae.00023.wav ...
# Converting data\genres\reggae\reggae.00024.wav ...
# Converting data\genres\reggae\reggae.00025.wav ...
# Converting data\genres\reggae\reggae.00026.wav ...
# Converting data\genres\reggae\reggae.00027.wav ...
# Converting data\genres\reggae\reggae.00028.wav ...
# Converting data\genres\reggae\reggae.00029.wav ...
# Converting data\genres\reggae\reggae.00030.wav ...
# Converting data\genres\reggae\reggae.00031.wav ...
# Converting data\genres\reggae\reggae.00032.wav ...
# Converting data\genres\reggae\reggae.00033.wav ...
# Converting data\genres\reggae\reggae.00034.wav ...
# Converting data\genres\reggae\reggae.00035.wav ...
# Converting data\genres\reggae\reggae.00036.wav ...
# Converting data\genres\reggae\reggae.00037.wav ...
# Converting data\genres\reggae\reggae.00038.wav ...
# Converting data\genres\reggae\reggae.00039.wav ...
# Converting data\genres\reggae\reggae.00040.wav ...
# Converting data\genres\reggae\reggae.00041.wav ...
# Converting data\genres\reggae\reggae.00042.wav ...
# Converting data\genres\reggae\reggae.00043.wav ...
# Converting data\genres\reggae\reggae.00044.wav ...
# Converting data\genres\reggae\reggae.00045.wav ...
# Converting data\genres\reggae\reggae.00046.wav ...
# Converting data\genres\reggae\reggae.00047.wav ...
# Converting data\genres\reggae\reggae.00048.wav ...
# Converting data\genres\reggae\reggae.00049.wav ...
# Converting data\genres\reggae\reggae.00050.wav ...
# Converting data\genres\reggae\reggae.00051.wav ...
# Converting data\genres\reggae\reggae.00052.wav ...
# Converting data\genres\reggae\reggae.00053.wav ...
# Converting data\genres\reggae\reggae.00054.wav ...
# Converting data\genres\reggae\reggae.00055.wav ...
# Converting data\genres\reggae\reggae.00056.wav ...
# Converting data\genres\reggae\reggae.00057.wav ...
# Converting data\genres\reggae\reggae.00058.wav ...
# Converting data\genres\reggae\reggae.00059.wav ...
# Converting data\genres\reggae\reggae.00060.wav ...
# Converting data\genres\reggae\reggae.00061.wav ...
# Converting data\genres\reggae\reggae.00062.wav ...
# Converting data\genres\reggae\reggae.00063.wav ...
# Converting data\genres\reggae\reggae.00064.wav ...
# Converting data\genres\reggae\reggae.00065.wav ...
# Converting data\genres\reggae\reggae.00066.wav ...
# Converting data\genres\reggae\reggae.00067.wav ...
# Converting data\genres\reggae\reggae.00068.wav ...
# Converting data\genres\reggae\reggae.00069.wav ...
# Converting data\genres\reggae\reggae.00070.wav ...
# Converting data\genres\reggae\reggae.00071.wav ...
# Converting data\genres\reggae\reggae.00072.wav ...
# Converting data\genres\reggae\reggae.00073.wav ...
# Converting data\genres\reggae\reggae.00074.wav ...
# Converting data\genres\reggae\reggae.00075.wav ...
# Converting data\genres\reggae\reggae.00076.wav ...
# Converting data\genres\reggae\reggae.00077.wav ...
# Converting data\genres\reggae\reggae.00078.wav ...
# Converting data\genres\reggae\reggae.00079.wav ...
# Converting data\genres\reggae\reggae.00080.wav ...
# Converting data\genres\reggae\reggae.00081.wav ...
# Converting data\genres\reggae\reggae.00082.wav ...
# Converting data\genres\reggae\reggae.00083.wav ...
# Converting data\genres\reggae\reggae.00084.wav ...
# Converting data\genres\reggae\reggae.00085.wav ...
# Converting data\genres\reggae\reggae.00086.wav ...
# Converting data\genres\reggae\reggae.00087.wav ...
# Converting data\genres\reggae\reggae.00088.wav ...
# Converting data\genres\reggae\reggae.00089.wav ...
# Converting data\genres\reggae\reggae.00090.wav ...
# Converting data\genres\reggae\reggae.00091.wav ...
# Converting data\genres\reggae\reggae.00092.wav ...
# Converting data\genres\reggae\reggae.00093.wav ...
# Converting data\genres\reggae\reggae.00094.wav ...
# Converting data\genres\reggae\reggae.00095.wav ...
# Converting data\genres\reggae\reggae.00096.wav ...
# Converting data\genres\reggae\reggae.00097.wav ...
# Converting data\genres\reggae\reggae.00098.wav ...
# Converting data\genres\reggae\reggae.00099.wav ...
# Converting data\genres\rock\rock.00000.wav ...
# Converting data\genres\rock\rock.00001.wav ...
# Converting data\genres\rock\rock.00002.wav ...
# Converting data\genres\rock\rock.00003.wav ...
# Converting data\genres\rock\rock.00004.wav ...
# Converting data\genres\rock\rock.00005.wav ...
# Converting data\genres\rock\rock.00006.wav ...
# Converting data\genres\rock\rock.00007.wav ...
# Converting data\genres\rock\rock.00008.wav ...
# Converting data\genres\rock\rock.00009.wav ...
# Converting data\genres\rock\rock.00010.wav ...
# Converting data\genres\rock\rock.00011.wav ...
# Converting data\genres\rock\rock.00012.wav ...
# Converting data\genres\rock\rock.00013.wav ...
# Converting data\genres\rock\rock.00014.wav ...
# Converting data\genres\rock\rock.00015.wav ...
# Converting data\genres\rock\rock.00016.wav ...
# Converting data\genres\rock\rock.00017.wav ...
# Converting data\genres\rock\rock.00018.wav ...
# Converting data\genres\rock\rock.00019.wav ...
# Converting data\genres\rock\rock.00020.wav ...
# Converting data\genres\rock\rock.00021.wav ...
# Converting data\genres\rock\rock.00022.wav ...
# Converting data\genres\rock\rock.00023.wav ...
# Converting data\genres\rock\rock.00024.wav ...
# Converting data\genres\rock\rock.00025.wav ...
# Converting data\genres\rock\rock.00026.wav ...
# Converting data\genres\rock\rock.00027.wav ...
# Converting data\genres\rock\rock.00028.wav ...
# Converting data\genres\rock\rock.00029.wav ...
# Converting data\genres\rock\rock.00030.wav ...
# Converting data\genres\rock\rock.00031.wav ...
# Converting data\genres\rock\rock.00032.wav ...
# Converting data\genres\rock\rock.00033.wav ...
# Converting data\genres\rock\rock.00034.wav ...
# Converting data\genres\rock\rock.00035.wav ...
# Converting data\genres\rock\rock.00036.wav ...
# Converting data\genres\rock\rock.00037.wav ...
# Converting data\genres\rock\rock.00038.wav ...
# Converting data\genres\rock\rock.00039.wav ...
# Converting data\genres\rock\rock.00040.wav ...
# Converting data\genres\rock\rock.00041.wav ...
# Converting data\genres\rock\rock.00042.wav ...
# Converting data\genres\rock\rock.00043.wav ...
# Converting data\genres\rock\rock.00044.wav ...
# Converting data\genres\rock\rock.00045.wav ...
# Converting data\genres\rock\rock.00046.wav ...
# Converting data\genres\rock\rock.00047.wav ...
# Converting data\genres\rock\rock.00048.wav ...
# Converting data\genres\rock\rock.00049.wav ...
# Converting data\genres\rock\rock.00050.wav ...
# Converting data\genres\rock\rock.00051.wav ...
# Converting data\genres\rock\rock.00052.wav ...
# Converting data\genres\rock\rock.00053.wav ...
# Converting data\genres\rock\rock.00054.wav ...
# Converting data\genres\rock\rock.00055.wav ...
# Converting data\genres\rock\rock.00056.wav ...
# Converting data\genres\rock\rock.00057.wav ...
# Converting data\genres\rock\rock.00058.wav ...
# Converting data\genres\rock\rock.00059.wav ...
# Converting data\genres\rock\rock.00060.wav ...
# Converting data\genres\rock\rock.00061.wav ...
# Converting data\genres\rock\rock.00062.wav ...
# Converting data\genres\rock\rock.00063.wav ...
# Converting data\genres\rock\rock.00064.wav ...
# Converting data\genres\rock\rock.00065.wav ...
# Converting data\genres\rock\rock.00066.wav ...
# Converting data\genres\rock\rock.00067.wav ...
# Converting data\genres\rock\rock.00068.wav ...
# Converting data\genres\rock\rock.00069.wav ...
# Converting data\genres\rock\rock.00070.wav ...
# Converting data\genres\rock\rock.00071.wav ...
# Converting data\genres\rock\rock.00072.wav ...
# Converting data\genres\rock\rock.00073.wav ...
# Converting data\genres\rock\rock.00074.wav ...
# Converting data\genres\rock\rock.00075.wav ...
# Converting data\genres\rock\rock.00076.wav ...
# Converting data\genres\rock\rock.00077.wav ...
# Converting data\genres\rock\rock.00078.wav ...
# Converting data\genres\rock\rock.00079.wav ...
# Converting data\genres\rock\rock.00080.wav ...
# Converting data\genres\rock\rock.00081.wav ...
# Converting data\genres\rock\rock.00082.wav ...
# Converting data\genres\rock\rock.00083.wav ...
# Converting data\genres\rock\rock.00084.wav ...
# Converting data\genres\rock\rock.00085.wav ...
# Converting data\genres\rock\rock.00086.wav ...
# Converting data\genres\rock\rock.00087.wav ...
# Converting data\genres\rock\rock.00088.wav ...
# Converting data\genres\rock\rock.00089.wav ...
# Converting data\genres\rock\rock.00090.wav ...
# Converting data\genres\rock\rock.00091.wav ...
# Converting data\genres\rock\rock.00092.wav ...
# Converting data\genres\rock\rock.00093.wav ...
# Converting data\genres\rock\rock.00094.wav ...
# Converting data\genres\rock\rock.00095.wav ...
# Converting data\genres\rock\rock.00096.wav ...
# Converting data\genres\rock\rock.00097.wav ...
# Converting data\genres\rock\rock.00098.wav ...
# Converting data\genres\rock\rock.00099.wav ...

# %%
def read_ceps(genre_list, base_dir=GENRE_DIR):
    X = []
    y = []
    for label, genre in enumerate(genre_list):
        genre_dir = Path(base_dir) / genre
        for fn in genre_dir.glob("*.ceps.npy"):
            ceps = np.load(fn)
            num_ceps = len(ceps)
            X.append(np.mean(ceps[int(num_ceps / 10):int(num_ceps * 9 / 10)], axis=0))
            y.append(label)

    return np.array(X), np.array(y)

# %% [markdown]
# ## Training the MFCC-based classifier

# %%
X, Y = read_ceps(GENRES)

train_avg, test_avg, cms = train_model(create_model, X, Y, "Log Reg CEPS", plot=18)
# Out:
# No handles with labels found to put in legend.
# Plotting classical
# Plotting jazz
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Plotting country
# Plotting pop
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# Plotting rock
# No handles with labels found to put in legend.
# Plotting metal
# 0.672	0.000	0.676	0.226

# %%
cm_avg = np.mean(cms, axis=0)
cm_norm = cm_avg / np.sum(cm_avg, axis=0)

plot_confusion_matrix(cm_norm, GENRES, "ceps","Confusion matrix of a CEPS based classifier", 19)
# Out:
# C:\local\Anaconda3-4.1.1-Windows-x86_64\lib\site-packages\matplotlib\cbook\deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
